# %% [markdown]
# # 7기 마에스트로 백엔드 과제 - 상품 카테고리 자동 분류 서버

# %% [markdown]
# # 과제 개요

# %% [markdown]
#  * 출제자 : 남상협 멘토 (justin@buzzni.com) / 버즈니 (http://buzzni.com) 대표
#  * 배경 : 카테고리 분류 엔진은 실제로 많은 서비스에서 사용되는 중요한 기계학습의 한 분야이다. 본 과제는 버즈니 개발 인턴이자 마에스트로 6기 멘티가 아래와 나와 있는 기본 분류 모델을 기반으로 deep learning 기반의 feature 를 더해서 고도화된 분류 엔진을 만들어서 2016 한국 정보과학회 논문으로도 제출 했던 과제다. 기계학습에 대한 학습과, 실용성 두가지 측면에서 모두 도움이 될 것으로 보인다.

# %% [markdown]
# ## 과제 목표

# %% [markdown]
#  * 입력 : 상품명, 상품 이미지
#  * 출력 : 카테고리
#  * 목표 : 가장 높은 정확도로 분류를 하는 분류 엔진을 개발

# %% [markdown]
# ## 제약 조건
#  * 분류 엔진은 rest api 형태로 만들어야함 (샘플로 준 python server 사용해도 됨)
#  * rest api 는  http://서버주소:포트/classify?name=상품명&img=상품이미지주소 형식으로 호출이 가능해야함
#  * 위 rest api 를 이용해서 별도로 가지고 있는 데이터로 자동 성능 평가로 채점을 하게됨 (채점하는 데이터는 제공되지 않음)
#  * 데이터 리턴 형식은 {u'cate': u'\ud328\uc158\uc758\ub958;\uc544\ub3d9\uc758\ub958;\ud55c\ubcf5'} 이런식으로 cate 라는 키 값에 그에 해당되는 대,중,소 카테고리를 ; 로 연결한 형태로 반환하면 됨

# %% [markdown]
# ## 평가 항목
#  1. 성능 평가 (100%)

# %% [markdown]
# ## 제출 항목
#  1. 채점 서버 호출이 필요함: 채점 서버 호출시 name 부분에 자신의 이름을 넣으면 됨.
#   - 자신이 개발한 서버 호출 형태 : http://서버주소:포트/classify?name=상품명&img=상품이미지주소
#   - 평가 서버 : http://somaeval.hoot.co.kr:8880/eval?url= 뒤에 자신의 서버 주소를 넣으면 됨 너무 자주 호출하면 서버가 죽을 수 있으니, mode=all 로는 꼭 필요할때만 호출하기 바람 , 평가 서버가 죽었을 시에는 justin@buzzni.com 으로 문의
#   - 예) 샘플 테스트 :  http://somaeval.hoot.co.kr:8880/eval?url=http://somaeval.hoot.co.kr:18887
#   - 예) 전체 테스트 : http://somaeval.hoot.co.kr:8880/eval?url=http://somaeval.hoot.co.kr:18887&mode=all&name=베이스라인

# %% [markdown]
# ## 성능 향상 포인트
#  * 오픈된 형태소 분석기(예 - 은전한닢 http://eunjeon.blogspot.kr/ )를 써서, 단어 띄어쓰기를 의미 단위로 띄어서 학습하기
#  * 상품명에서 분류하는데 도움이 되지 않는 stop word 제거하기
#  * bigram, unigram, trigram 등 단어 feature 를 더 다양하게 추가하기
#  * 이미지 데이터를 Deep Learning (CNN) 기반 방법으로 feature 를 추출해서 추가하기
#   * 제일 기본적으로 https://github.com/irony/caffe-docker-classifier 이런 이미 만들어진 모델을 이용해서 feature 를 추출해서 추가하기도 가능함
#   * DIGITS + caffe 를 이용해서 본 학습 모델에 맞는 이미지 자동 분류기를 별도로 학습해서 사용하는것도 가능함

# %% [markdown]
# ## 개발 서버 URL 형태
#  * name, img 를 파리미터로 호출한다.
#  * 호출 형태 : http://somaeval.hoot.co.kr:18887/classify?name=조끼&img=http://shopping.phinf.naver.net/main_8134935/8134935099.1.jpg

# %% [markdown]
# ## 성능평가 테스트 서버
#  * 아래 주소에서 url 에 자신의 분류기 모델 주소를 넣어주면 제공되지 않았던 데이터들을 이용해서 평가를 해준다.
#  * 샘플 테스트(카테고리별 2개만 가지고 테스트) : http://somaeval.hoot.co.kr:8880/eval?url=http://somaeval.hoot.co.kr:18887
#  * 전체 성능 평가 테스트 (mode=all) : http://somaeval.hoot.co.kr:8880/eval?url=http://somaeval.hoot.co.kr:18887&mode=all

# %% [markdown]
# ## 현재 보고 있는 IPython Notebook 사용법
#  * https://www.youtube.com/results?search_query=ipython+notebook+tutorial
#  * shift + enter 를 누르면 실행이 된다.

# %% [markdown]
# # 아래는 baseline 모델을 만드는 방법

# %%
import pandas as pd

# %% [markdown]
# ## 데이터를 읽는다.
#  * 아래 id 에 해당되는 이미지 데이터 다운받기 https://www.dropbox.com/s/q0qmx3qlc6gfumj/soma_train.tar.gz

# %%
train_df = pd.read_pickle("soma_goods_train.df")

# %% [markdown]
#  * cate1 는 대분류, cate2 는 중분류, cate3 는 소분류
#  * 총 10000개의 학습 데이터

# %%
train_df.shape
# Out:
# (10000, 4)

# %%
train_df
# Out:
#          cate1 cate2 cate3                                               name
# 90985   디지털/가전  PC부품   CPU                    인텔 인텔 코어i7-4세대 4770K (하스웰) (정품)
# 90986   디지털/가전  PC부품   CPU  애플 맥북에어 13형 MacBook Air 13.3/1.6/4/256FLASH MJ...
# 90987   디지털/가전  PC부품   CPU  애플 맥북에어 11형 MacBook Air 11.6/1.6/4/128FLASH MJ...
# 90988   디지털/가전  PC부품   CPU  [ICODA] [대리점정품]인텔 제온 E5-2630V3 하스웰-EP (2.4GHz/...
# 90989   디지털/가전  PC부품   CPU  ICODA [대리점정품]인텔 제온 E5-2630V3 하스웰-EP (2.4GHz/8C...
# 90990   디지털/가전  PC부품   CPU                         인텔 intel 코어4세대 하스웰 i3-4160
# 90991   디지털/가전  PC부품   CPU                   인텔 코어i3-4세대 4160 (하스웰 리프레시) (정품)
# 90992   디지털/가전  PC부품   CPU                인텔 코어i3-4세대 4160 (하스웰 리프레시) (수입/박스)
# 90993   디지털/가전  PC부품   CPU  애플 맥북에어 13형 MJVG2KH/A + AirPort Time Capsule -...
# 90994   디지털/가전  PC부품   CPU  [해외] Intel Intel Xeon Qc E3-1270 Processor    ...
# 90995   디지털/가전  PC부품   CPU  [해외]IntelIntel Pentium Dual Core G2030 LGA 115...
# 90996   디지털/가전  PC부품   CPU  [해외]IntelIntel PENTIUM SL7EP:M Processor 735 1...
# 90997   디지털/가전  PC부품   CPU  [해외]IntelIntel Pentium Processor G3258 4 BX806...
# 90998   디지털/가전  PC부품   CPU               [4%즉시할인쿠폰]인텔 제온 E3-1226V3 (하스웰) (정품)
# 90999   디지털/가전  PC부품   CPU  [해외]IntelIntel?? Xeon?? Processor X5570 (8M Ca...
# 842706    패션의류  아동의류    한복             [KB국민카드 5%할인, 3/14]Fidelia프론트리프팅로얄블루세트
# 842707    패션의류  아동의류    한복  [5% 즉시할인](현대Hmall)[名品한복의 대명사 아씨우리옷] 아동한복 소품 머리...
# 842708    패션의류  아동의류    한복  [BC카드5%할인][예화-좋은아이들] 名品 남아 아동한복 색동비취 6015 (배자+...
# 842709    패션의류  아동의류    한복           [예화-좋은아이들] 여아 아동한복_ 3030 은별 녹두 저고리+치마[[]
# 842710    패션의류  아동의류    한복            [신한카드5%할인][예화-좋은아이들] 아동한복 여아 1076 빛이나노랑
# 842711    패션의류  아동의류    한복                   베네통키즈 멀티프린트경량신발주머니(QCBG23511.PK)
# 842712    패션의류  아동의류    한복              [드레스하우스]드레스하우스)hm68 꿈나래_나비코사지 비취배자 한복
# 842713    패션의류  아동의류    한복  [프렌치캣] [2015년 여름 기획상품]BL 우븐 PT(Q52DKP320) [갤러리...
# 842714    패션의류  아동의류    한복              [신한카드5%할인][늘사랑] 금박 꽃수 당의(1380-07 아동여)
# 842715    패션의류  아동의류    한복  [BC카드5%할인][예화-좋은아이들] 남아 퓨전 아동한복_ 2065 양귀비 (배자+...
# 842716    패션의류  아동의류    한복  [BC카드5%할인][예화-좋은아이들] 名品 전통 남아 아동한복_ 5008 금직수박 ...
# 842717    패션의류  아동의류    한복   [예화-좋은아이들] 名品 전통 남아 아동한복_ 5008 금직수박 배자+저고리+바지[[]
# 842718    패션의류  아동의류    한복  [5% 즉시할인]아씨우리옷  아씨우리옷  패션플러스  名品한복의 대명사 아씨우리옷 ...
# 842719    패션의류  아동의류    한복                [신한카드5%할인][서우한복] 아동한복 여자아동 금나래 (분홍)
# 842720    패션의류  아동의류    한복        [현대백화점 VI관] 게스키즈 G47KAT010W2 여 A라인 전사나염 티셔츠
# 842721    패션의류  아동의류    한복         베네통키즈 키즈 러블리 와펜 쿠션지 맨투맨티셔츠 QATS19511IVNYPK
# 842722    패션의류  아동의류    한복         [현대백화점 I관] 베네통키즈 (QATS19511)러블리와펜쿠션지맨투맨티셔츠
# 842723    패션의류  아동의류    한복            [현대백화점 V관] 파코라반베이비 룰라니트가디건 PP1-43204 핑크
#
# [10000 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
#  * CountVectorizer 는 일반 text 를 이에 해당되는 숫자 id 와, 빈도수 형태의 데이터로 변환 해주는 역할을 해준다.
#  * 이 역할을 하기 위해서 모든 단어들에 대해서 id 를 먼저 할당한다.
#  * 그리고 나서, 학습 데이터에서 해당 단어들과, 그것의 빈도수로 데이터를 변환 해준다. (보통 이런 과정을 통해서 우리가 이해하는 형태를 컴퓨터가 이해할 수 있는 형태로 변환을 해준다고 보면 된다)
#  * 예를 들어서 '베네통키즈 키즈 러블리 키즈' 라는 상품명이 있고, 각 단어의 id 가 , 베네통키즈 - 1, 키즈 - 2, 러블리 -3 이라고 한다면 이 상품명은 (1,1), (2,2), (3,1) 형태로 변환을 해준다. (첫번째 단어 id, 두번째 빈도수)

# %%
vectorizer = CountVectorizer(ngram_range=(1, 3),token_pattern=r'(?u)\b\w+\b', min_df=1)

# %% [markdown]
#  * 대분류, 중분류, 소분류 카테고리 명을 합쳐서 카테고리명을 만든다.  우리는 이 카테고리명을 예측하는 분류기를 만들게 된다.
#  * d_list 에는 학습하는 데이터(상품명) 을 넣고, cate_list 에는 분류를 넣는다.

# %%
d_list = []
cate_list = []
for each in train_df.iterrows():
    cate = ";".join([each[1]['cate1'],each[1]['cate2'],each[1]['cate3']])
    d_list.append(each[1]['name'])
    cate_list.append(cate)

# %%
print len(set(cate_list))
analyze = vectorizer.build_analyzer()
analyze(u'김치 참치 삼치 22 cheer up zz')
# Out:
# 108
# [u'\uae40\uce58',
#  u'\ucc38\uce58',
#  u'\uc0bc\uce58',
#  u'22',
#  u'cheer',
#  u'up',
#  u'zz',
#  u'\uae40\uce58 \ucc38\uce58',
#  u'\ucc38\uce58 \uc0bc\uce58',
#  u'\uc0bc\uce58 22',
#  u'22 cheer',
#  u'cheer up',
#  u'up zz']

# %% [markdown]
#  * 각 카테고리명에 대해서 serial 한 숫자 id 를 부여한다.
#  * cate_dict[카테고리명] = serial_id 형태이다.

# %%
cate_dict = dict(zip(list(set(cate_list)),range(len(set(cate_list)))))

# %%
print cate_dict[u'디지털/가전;네트워크장비;KVM스위치']
print cate_dict[u'패션의류;남성의류;정장']
# Out:
# 0
# 80

# %% [markdown]
#  * y_list 에는 단어 형태의 카테고리명에 대응되는 serial_id 값들을 넣어준다.

# %%
y_list = []
for each in train_df.iterrows():
    cate = ";".join([each[1]['cate1'],each[1]['cate2'],each[1]['cate3']])
    y_list.append(cate_dict[cate])

# %% [markdown]
#  * fit_transform 을 하게 되면, d_list 에 들어 있는 모든 단어들에 대해서, 단어-id 사전을 만드는 일을 먼저하고 (fit)
#  * 실제로 d_list 에 들어 있는 각 데이터들에 대해서 (단어id,빈도수) 형태의 데이터로 변환을 해준다. (transform)

# %%
import nltk
nltk.download()

# %%
from konlpy.tag import Twitter
from nltk.corpus import stopwords

stop_words = stopwords.words('english')+ [u'1',u'2',u'3',u'4',u'5',u'6',u'7',u'8',u'9']

def set_konlpy(text):
    words = Twitter().pos(text)
    check = ['Alpha','Number','Noun']
    nn = [e[0] for e in words if e[1] in check if e[0] not in stop_words]
    return ' '.join(nn)

n_list = []
for each in d_list:
    n_list.append(set_konlpy(each))
    print (set_konlpy(each))
# Out:
# 인텔 인텔 코어 7 4 세대 4770 K 하스웰 정품
# 애플 맥북에어 13 형 MacBook Air 13 3 1 6 4 256 FLASH MJVG 2 KH A 기존 1490000 원
# 애플 맥북에어 11 형 MacBook Air 11 6 1 6 4 128 FLASH MJVM 2 KH A 기존 1130000 원
# ICODA 대리점 정품 인텔 제온 E 5 2630 V 3 하스웰 EP 2 4 GHz 8 C 20 MB LGA 2011 V 3 쿨 러미 포함
# ICODA 대리점 정품 인텔 제온 E 5 2630 V 3 하스웰 EP 2 4 GHz 8 C 20 MB LGA 2011 V 3 쿨 러미 포함
# 인텔 intel 코어 4 세대 하스웰 3 4160
# 인텔 코어 3 4 세대 4160 하스웰 리프 레시 정품
# 인텔 코어 3 4 세대 4160 하스웰 리프 레시 수입 박스
# 애플 맥북에어 13 형 MJVG 2 KH A AirPort Time Capsule 3 TB 기존 1490000 원
# 해외 Intel Intel Xeon Qc E 3 1270 Processor T 1 구매 대행 직구
# 해외 IntelIntel Pentium Dual Core G 2030 LGA 1155 Processor BX 80637 G 2030
# 해외 IntelIntel PENTIUM SL 7 EP M Processor 735 1 7 GHz 400 MHz 2 MB
# 해외 IntelIntel Pentium Processor G 3258 4 BX 80646 G 3258
# 4 즉시 할인 쿠폰 인텔 제온 E 3 1226 V 3 하스웰 정품
# 해외 IntelIntel Xeon Processor X 5570 8 M Cache 2 93 GHz 6 40 GT Intel QPI FC LGA 1366
# 4 즉시 할인 쿠폰 인텔 코어 2 듀오 E 7400 울프 데일
# 해외 IntelIntel Core 7 4790 K Processor 8 M Cache 4 40 GHz BX 80646 I 74790 K
# 해외 IntelIntel Core 3 4370 3 8 GHz Desktop Haswell Processor BX 80646 I 34370
# 해외 IBMIBM Xeon E 5 2620 2 GHz Processor Upgrade Socket 90 Y 5945
# 해외 IntelIntel Core 5 4690 Processor 6 M Cache 3 90 GHz BX 80646 I 54690
# 해외 IntelIntel Core 7 5930 K Haswell E 6 Core 3 5 GHz LGA 2011 v 3 140 W Desktop Processor BX 80648 I 7593
# 해외 IBMIBM Xeon E 5 2650 2 GHz 8 LGA 2011 Processor 69 Y 5329
# 해외 IntelIntel I 7 950 LGA 1366 3 06 G 8 MB 4 8 GT SEC INTEL PROCESSOR
# 해외 IntelIntel Core 7 4900 MQ 2 80 GHz Processor 2 8 4 NA BX 80647 I 74900 MQ
# 해외 HPHP Xeon E 5 2620 V 2 2 1 GHz 6 LGA 2011 Processor 709493 B 21
# 4 즉시 할인 쿠폰 Intel Pentium G 3258 3 2 GHz Processor BX 329456
# 인텔 코어 3 아이비브릿지 3220
# 인텔 펜티엄 하스웰 G 3220
# 인텔 제온 하스웰 E 3 1230 V 3
# AMD 비쉐라 8350
# AMD 리치랜드 6400 K
# AMD FX 9370 비셰라
# 인텔 코어 2 울프 데일 E 7500
# 4 즉시 할인 쿠폰 AMD FX 4300 비쉐라 정품
# 인텔 정품 E 8200 E 8300 E 8400 E 8500 중고 CPU 코어 2 듀오 배송 AS 완벽 호환 인텔 정품
# 4 즉시 할인 쿠폰 인텔 코어 5 4 세대 4690 하스웰 리프 레시 정품 KY
# 4 즉시 할인 쿠폰 코어 5 인텔 코어 5 4 세대 4690 하스웰 리프 레시 정품 KY
# CDR AMD FX 6350 비쉐라 벌
# 인텔 펜티엄 하스웰 리프 레시 G 3450
# 인텔 코어 2 쿼드 요크필드 Q 8200
# 4 즉시 할인 쿠폰 해외 직 배송 Dell XPS 13 TouchScreen Laptop Intel Core 7 4510 U Processor 2 0 GHz 8 GB Ram 13
# 4 즉시 할인 쿠폰 CDR AMD FX 8370 비쉐라 정품
# YBH 인텔 코어 5 4 세대 4460 하스웰 리프 레시 정품
# 해외 IntelIntel Pentium III Processor 933 MHz 256 K Cache 133 MHz FSB
# ICODA 벌 정품 쿨러 포함 인텔 펜티엄 하스웰 리프 레시 G 3240 CPU 3 1 GHz 3 MB LGA 1150
# 4 즉시 할인 쿠폰 인텔 코어 5 4 세대 4590 하스웰 리프 레시 정품 KY
# 인텔 코어 3 3 세대 3220 아이비브릿지 벌 쿨러 X
# 코어 3 아이비브릿지 3220 3 30 GHz LGA 1155 3 MB 벌 인텔 1155 정품 쿨러 포함
# ICODA 대리점 정품 인텔 코어 5 하스웰 4670 CPU 3 4 GHz 6 MB LGA 1150
# 코어 5 하스웰 4670 3 4 GHz LGA 1150 6 MB 벌 정품 쿨러
# 인텔 코어 5 4 세대 4670 하스웰 벌
# 4 즉시 할인 쿠폰 intel 코어 4 세대 하스웰 3 4370 인텔
# 인텔 코어 3 4 세대 4370 하스웰 리프 레시 정품
# 인텔 코어 3 4 세대 4370 하스웰 리프 레시 정품 단골 방문 수령 당일 출고
# 피씨 사자 인텔 코어 3 4 세대 4370 하스웰 리프 레시 정품 배송 로또 추첨 응모 증정
# 인텔 인텔 코어 3 4 세대 4370 하스웰 리 프레 스 정품
# PC 랜드 인텔 코어 5 4 세대 4430 하스웰 정품 컴퓨터 조립 부품 용품 케이블
# 해외 세금 포함 일본 정품 Intel CPU Core 5 4430 3 00 GHz 6 M 캐시 LGA 1150 Haswell BX 80646 I 54430 BOX
# 해외 Intel Core 5 4430 Quad Core Desktop Processor 3 0 GHz 6 MB Cache LGA 1150 BX 80646 I 54430
# AMD 노 A 6 3500 정품 박스 2 1 GHz L 2 3 MB 소켓 FM 1
# 코어 5 3 세대 3470 아이비브릿지
# SJC 인텔 코어 5 3 세대 3470 아이비브릿지 정품
# 인텔 코어 5 3 세대 3470 아이비브릿지 벌
# intel 코어 아이비브릿지 5 3470 3 2 GHz 22 nm High KLGA 1155 인텔 그래픽스 HD 2500
# AMD AMD A 4 5300 트리니티 3 4 GHz 1 MB 듀얼 코어 AMD HD 7480 D 소켓 FM 2
# AMD A 4 5300 트리니티 정품 대리점 정품
# 대리점 3 사 정품 인텔 코어 3 3 세대 3220 3240 대체 발송 아이비브릿지 듀얼코어 INTEL CPU 1155 3 3 G 2015 년 3 월 신 학기 상품
# INTEL 코어 4 세대 5 4690 벌 하스웰 리플 레시 3 5 GHz 6 MB 쿨 러미 포함
# 인텔 CPU 코어 5 4 세대 하스웰 리프 레시 4690 LGA 1150 3 5 GHz INTEL
# intel 코어 4 세대 하스웰 5 4690 인텔
# 인텔 코어 5 4 세대 4690 하스웰 리프 레시 정품
# ECOPC 당일 출고 새 제품 정품 인텔 코어 7 4 세대 4790 하스웰 리프 레시 정품
# 이노 퍼스트 INTEL 코어 4 세대 7 4790 정품 박스 하스웰 리프 레시 3 6 GHz 8 MB 쿨러 포함
# ECOPC 당일 출고 새 제품 정품 인텔 코어 7 4 세대 4790 하스웰 벌 쿨러 당일 출고 새 제품
# 이노 퍼스트 INTEL 코어 4 세대 7 4790 쿨컴정품 박스 병행수입 하스웰 리프 레시 3 6 GHz 8 MB 쿨러 포함
# 인텔 코어 7 4 세대 4790 하스웰 리프 레시 대리점 정품
# 해외 AMD A 4 6300 Dual Core APU Processor 3 7 GHz Sockect FM 2 Retail
# 정품 AMD 리치랜드 A 4 6300 3 7 GHz 1 MB 소켓 FM 2 65 W
# AMD A 4 6300 리치랜드 정품
# 인텔 코어 5 4 세대 4590 하스웰 리프 레시 벌
# 인텔 CPU 코어 5 4 세대 하스웰 리프 레시 4590 LGA 1150 3 3 GHz INTEL
# 인텔 코어 5 4 세대 4590 하스웰 리프 레시 수입 박스
# 인텔 코어 5 4 세대 4460 하스웰 리프 레시 벌
# INTEL 인텔 CPU 코어 5 4 세대 4460 하스웰 리프 레시 TRAY 벌 쿨 러미 포함 A S 1 년
# INTEL 인텔 CPU 코어 5 4 세대 4460 하스웰 리프 레시 TRAY 벌 쿨 러미 포함 A S 1 년
# 4 즉시 할인 쿠폰 인텔 코어 7 4 세대 4770 K 하스웰 정품
# 이노 퍼스트 INTEL 코어 4 세대 7 4770 K 정품 박스 하스웰 3 5 GHz 8 MB 쿨러 포함
# 4 즉시 할인 쿠폰 피씨 사자 인텔 코어 7 4 세대 4770 K 하스웰 벌
# 이노 퍼스트 INTEL 코어 4 세대 7 4770 쿨컴정품 박스 병행수입 하스웰 3 4 GHz 8 MB 쿨러 포함
# INTEL 인텔 CPU 코어 7 4 세대 4790 K 데빌 스 캐년 TRAY 벌 쿨 러미 포함 A S 1 년
# 코어 7 인텔 7 4 세대 4790 K 데빌 스 캐년 정품 가격 당일 발송
# 인텔 코어 7 4 세대 4790 K 하스웰 리프 레시 데빌 스 캐년 수입 박스
# EM 인텔 코어 7 4 세대 4790 K 데빌 스 캐년 정품 당일 발송
# 인텔 코어 5 3 세대 3570 아이비브릿지 병행수입
# 아이디 존 인텔 코어 5 3 세대 3570 아이비브릿지 벌 기업 아이디 존
# 코어 5 3 세대 3570 아이비브릿지
# INTEL 코어 3 세대 5 3570 정품 박스 아이비브릿지 3 40 GHz 6 MB 쿨러 포함
# 컴퓨존 INTEL 코어 3 세대 5 3570 벌 아이비브릿지 3 40 GHz 6 MB 쿨 러미 포함
# 벌 쿨 러미 포함 인텔 코어 5 3570 아이비브릿지 CPU 3 4 GHz 6 MB LGA 1155
# 4 즉시 할인 쿠폰 인텔 코어 3 4 세대 4160 하스웰 리프 레시 벌 쿨러 가격 당일 발송
# 디제이 코리아 Pioneer DDJ SX 2
# 해외 SchiitMagni Headphone Amplifier
# 해외 ShureShure SE 535 V Earphones FiiO E 17 Amp Dac L 1 Y Cables Bundle Bronze
# 해외 구매 대행 B 00 AZVM 8 PY ADEL 2020 ANZ
# 해외 구매 대행 B 00 AZVKJOQ ADM 1485 JNZ
# 해외 구매 대행 B 00 AZVH 06 G AD 586 JRZ
# 해외 구매 대행 B 00 AZVGFEE INA 114 AU
# 해외 구매 대행 B 00 AZVJO 06 AD 8630 ARUZ
# 해외 구매 대행 B 005 T 5 EGGK MCHC 908 JK 8 CPE
# 해외 구매 대행 B 00 AZVDOG 6 SN 74 AS 756 N
# 해외 구매 대행 B 00 AZVJKUK AD 7991 YRJZ 0500 RL 7
# 해외 구매 대행 B 00 AZVG 0 Z 8 AD 626 ANZ
# 해외 구매 대행 B 00 MMUXVAC Supervisory Circuits 3 V VTG Monitor MPU 5 pieces
# 해외 구매 대행 B 00 MMV 39 JY Voltage References Ultracompact Prec 2 5 V 5 pieces
# 해외 구매 대행 B 00 AZV 81 XC MAX 1703 ESE
# 해외 구매 대행 B 00 AZVJVY 0 AD 7948 BRZ
# 4 즉시 할인 쿠폰 해외 SMSL SA 36 A 2 20 W TA 2020 Tripath Class T Amp Stere 최저 해외 구매 대행 전문 서비스
# 해외 FiiO E 11 K Kilimanjaro 2 OPA 1642 AD 8397 HiFi Portable Headphone Amplifier NEW
# 해외 IRS 2092 200 W Class D mono amplifier board
# 해외 YJ TPA 3116 D 50 W 50 W Class D class Amplifier Completed Board w Audio Adjustment Function
# 해외 Portable Active Headphone Amplifier Stereo Hifi Mini Headhpone AMP Headset amplifiers Class A po
# 해외 50 W x 2 Hi Fi 2 Channel Digital Power Amplifier w 24 V 4 A Power Supply SKU 11266
# 해외 Little Dot MK VII Balanced Headphone Amplifier
# 4 즉시 할인 쿠폰 해외 Pro Ject Audio Stream Box DS Music Streaming C 최저 해외 구매 대행 전문 서비스
# 해외 구매 대행 B 00 AZVF 6 EE ADR 430 ARZ
# 해외 구매 대행 B 00 MMUXH 6 U LVDS Interface IC 100 Mbps Full Duplex 3 3 V Hi Spd 5 pieces
# 해외 구매 대행 B 00 AZVFD 3 I AD 7783 BRUZ
# 해외 구매 대행 B 00 MMVH 2 S 8 Voltage References 4 5 V Prec Micropwr LDO Low VRef 5 pieces
# 해외 구매 대행 B 00 AZVD 0 IS OP 484 FSZ
# 해외 구매 대행 B 005 TABKXW UC 3824 DW
# 나드 NAD M 2 디지털 티 앰프
# 스쿨 뮤직 Roland CUBE 10 GX 롤랜드 큐브 멀티 이펙터 내장 기타 앰프
# 스쿨 뮤직 VOX amPlug 2 Classic Rock AP 2 CR 헤드폰 기타 앰프
# l 소리아 l TOany 투 애니 TD 384 DAC DDC
# 셰에라자드 FiiO D A 컨버터 헤드폰 앰프 E 17 K 프리미엄 공식 대리점 청담동 셰에라자드 청음 실 운영
# 셰에라자드 FiiO 무 손실 디지털 플레이어 X 1 프리미엄 공식 지정 대리점 청담동 청음 실 운영
# 해외 구매 대행 B 00 LWK 5 QWE Board Mount Hall Effect frasl Magnetic Sensors Hall Sensor Interfac
# WINEAUDIO 티악 Teac DAC DSD 디지털 컨버터 UD 301
# 해외 구매 대행 B 00 AZVG 6 ZM AD 5308 ARUZ REEL 7
# 해외 구매 대행 B 00 AZVET 42 ADR 440 ARZ
# 해외 구매 대행 B 00 AZVG 74 C AD 623 BRZ
# 해외 구매 대행 B 00 AZVHZ 2 K AD 8047 ARZ
# 해외 구매 대행 B 00 AZVJJI 8 ADA 4096 4 ARUZ
# 해외 구매 대행 B 00 AZVCEEO OP 747 ARUZ
# 해외 구매 대행 B 00 AZVJKEQ AD 7991 YRJZ 1500 RL 7
# 해외 구매 대행 B 005 T 94 RV 0 MAX 203 EPP G 36
# 해외 구매 대행 B 00 AZVKTRI AD 7397 ARZ
# 해외 구매 대행 B 00 MMUZ 3 OY LDO Voltage Regulators 1 A CMOS Linear Reg 5 pieces
# 해외 구매 대행 B 00 MEKOPIW Clock Buffer 2 Selectable Inputs 12 LVPECL Outpt SiGe
# 해외 구매 대행 B 00 MN 4 P 7 YK RS 232 Interface IC IC 5 V PWR RS 232 frasl RS 422 TNSCVR
# 해외 구매 대행 B 00 MMVD 3 ZY Voltage References 5 V Prec VRef frasl Temp Transducer 5 pieces
# WINEAUDIO 온쿄 Onkyo AV 리시버 TX SR 333
# 해외 E 19 Class A amp board
# 해외 1 PC silver DIY Headphone Amplifier Chassis Enclosure 66 27 105 mm
# 해외 TDA 7492 Class D MINI Digital Amplifier Board 2 35 W DC 18 V DC 24 V
# 해외 TPA 3116 Amplifier Assembled Board 50 W 50 W Official Version Amp Board SKU 11487
# 해외 5 pcs lot DC 12 V Mini Amplifier Board 10 W 10 W Class D Amplifier 10000117
# 해외 JHL Class A Headphone amplifier PRE AMP KIT DIY
# 해외 Top quality HDMI digital audio decoder HDMI TO HDMI VGA SPDIF 5 1 CH HP converter 1080 P
# 해외 LP 2020 A Lepai Tripath Class T Hi Fi Audio Mini Amplifier
# 해외 구매 대행 B 00 AZVL 4 ZO AD 9740 ARZ
# 해외 구매 대행 B 00 AZVKYUU AD 9750 ARZ
# 해외 구매 대행 B 005 TAFTIO UC 3823 BDW
# 해외 구매 대행 B 00 AZV 9 O 06 SMP 04 EPZ
# 오디오 랩 AudioLab 8200 A 인티 앰프 공식 수입 정품 무료 배송
# 해외 구매 대행 B 00 MEK 6 RLK Audio Sample Rate Converters 192 kHz 8 1 Stereo Async Smpl Rate Conv
# WINEAUDIO 코드 Chord DSD DAC QEX DAC
# 4 즉시 할인 쿠폰 해외 HDMI Audio Converter 최저 해외 구매 대행 전문 서비스
# 인터파크 단 독특 FiiO E 11 K 한국 공식 수입 포터블 헤드폰 앰프 FiiO E 11 K 한국 공식 수입 구입
# ADL Formula 2 USB 케이블 A B 타입 1 2 FURUTECH 후루텍 의 자회사 ADL 의 RCA 인터 FURUTECH 후루텍 의 자회사 ADL 의 RCA
# 해외 구매 대행 B 00 EABSK 02 TLC 0820 ACN
# 해외 구매 대행 B 00 AZVJHE 4 AD 8642 ARZ
# 해외 구매 대행 B 00 HKJDMQI Voltage References EP 2 5 V w frasl Crnt Sink amp Srce Capability
# 해외 구매 대행 B 00 AZVFGN 0 AD 822 ARZ REEL 7
# 해외 구매 대행 B 00 AZVLBCU AD 7303 BNZ
# 해외 구매 대행 B 005 TAEMUA UC 3863 DW
# 해외 구매 대행 B 00 MEKH 0 J 8 Voltage References Low Noise 5 00 V Ultraprecision
# 4 즉시 할인 쿠폰 해외 SMAKN MUSE T AMP MU 15 MK 2 TA 2024 Class T HI FI St 최저 해외 구매 대행 전문 서비스
# 해외 구매 대행 B 00 AZVJ 2 N 0 ADV 7123 KSTZ 140
# 해외 구매 대행 B 00 MMUWYWI Supervisory Circuits 5 V CMOS MPU IC 5 pieces
# 해외 구매 대행 B 00 MMV 3 FCU Voltage Regulators Switching Regulators CMOS Switched Capacitor VTG C
# 해외 구매 대행 B 00 MMVD 9 OY Voltage References 5 V Prec VRef frasl Temp Transducer 5 pieces
# 해외 구매 대행 B 00 AZVMNF 4 ADR 445 BRZ REEL 7
# 해외 구매 대행 B 00 AZVK 1 BC AD 7943 BNZ
# 해외 SMSL M 8 DAC ES 9018 SMSL VMV VA 2 Headphone Amplifier Free Shipping
# 해외 TPA 3116 Amplifier Assembled Board 50 W 50 W Official Version Amp Board
# 해외 A 1 Pure A Class Amplifier Board 20 W 2 Amp Assembled Board
# 해외 Xmas USB IEEE 1284 Parallel Port Adapter Converter Printer Cable
# 해외 HIFI Class 2 0 Stereo Digital Amplifier TPA 3116 Advanced 50 W 50 W
# 해외 Edifier Hall HA 11 Headphone Amplifier AMP For HD 595 hd 580 220 v ac input
# 해외 Brand New Edifier Hall HA 11 Headphone Amplifier Hi Fi LN 000155
# 해외 TPA 3116 D 2 digital power amplifier board hollow inductance upgrade TA 2021 finished product
# 해외 E 6 Portable Headphone FiiO Amplifier Black
# 해외 Supply US AC 100 240 V Converter Adapter DC 12 V 1 A Power
# 해외 1 PCS Lot 1 x 3 SPDIF Toslink Splitter 1 3 optical splitter supports 5 1 power adapter
# 해외 구매 대행 B 00 AZVDI 2 G OP 42 GPZ
# 해외 구매 대행 B 00 MMUXUC 6 LVDS Interface IC 200 Mbps Full Duplex 3 3 V Hi Spd 5 pieces
# 해외 구매 대행 B 00 AZVM 4 NU AD 7829 BRZ
# 해외 구매 대행 B 00 MMUWRIO RS 422 frasl RS 485 Interface IC 3 3 V 15 kV ESD Full Duplex 250 kbps 5
# 해외 구매 대행 B 005 S 3 U 2 PW UC 2824 DW
# 캐논 EOS 6 D
# 캐논 EOS 7 D Mark II
# 니콘 D 5200
# 니콘 D 3200
# 니콘 D 610
# 니콘 D 3000
# 캐논 EOS 1 D MARK IV
# 캐논 EOS 1 D Mark III
# 소니 알파 A 37
# 정품 NIKON D 5300 최신 새 상품 공식 정품 판매 파라파라 M
# Pentax 펜탁스 DSLR K 50 18 55 WR 컬러 렌즈 킷
# 4 즉시 할인 쿠폰 정품 캐논 100 D 18 55 IS 50 8 55 250 mmIS
# PR 정품 NIKON D 600 BODY 풀프레임 방문 수령 퀵 가능 친절 상담 PARAPARA M 1
# 해외 13456 Nikon D 810 DSLR Filmmakers Kit 13456 87480
# DSLR D 5500 2416 만 화소 18 55 mm 터치 패널 와이드 멀티 앵글 액정 모니터 Wi Fi 니콘
# 4 즉시 할인 쿠폰 D 810 렌즈 포함 정품 니콘 DSLR D 810 24 120 mm VR Kit 정품 당일 배송
# Pedco 펫코 카메라 고정 나사 P UMOUNT STD
# 호루스 누 ND 2000 필터 77 mm 전용 케이스 포함
# 호루스 누 150 x 200 mm 사각 필터 150 GN 4 그라데이션 그레이 ND 4 Gradual Grey ND 4 전용 케이스 포함
# 정품 후지필름 파 픽스 S 1
# D 4 S BODY 렌즈 포함 단품 니콘
# 해외 1515 Nikon D 7100 DSLR Camera 18 105 mm f 3 5 5 6 G ED VR DX 1515 87439
# 해외 Tripp LiteTripp Lite PDUMV 15 PDU Metered 120 V 15 A 5 15 R 16 Outlet 5 15 P Vertical 0 URM
# 해외 해외 니콘 D 7100 24 1 MP DX 포맷 CMOS 디지털 SLR 18 140 f 3 5 5 6 G ED VR A
# 해외 Olympus MSC ED M 75 300 mm II f 4 8 6 7 Zoom Lens 2051544
# DSLR D 5500 2416 만 화소 터치 패널 와이드 멀티 앵글 액정 모니터 Wi Fi 8 G 메모리 가방 크리 닝킷 추가 정품 배터리 증정
# 정품 EOS 100 D Kit EF 40 mm F 2 8 STM 화이트 SDHC 32 GB C 10 SD 리더 기 UV 필터 6520 가방 DSLR 삼각대 사은 품
# 신한카드 5 할인 정품 파워 풀 패키지 EOS 70 D BODY 메모리 16 G 파워 풀 패키지
# 국민카드 5 니콘 NIKON Sandisk Extreme SDXC 64 GB 2 개 증정 정품 니콘 D 610 Body 포켓 융 인화 웹하드 이용권
# 캐논 롯데 백화점 캐논 100 D 더블 18 55 IS STM EF 40 mm 가방 SD 4 G 융 크리 닝 가이드북
# 니콘 정품 WU 1 B 증정 정품 니콘 DSLR D 610 Body 인화 웹하드
# 블루투스 이어폰 및 EN EL 15 배터리 증정 정품 니콘 DSLR D 810 Body AF S 50 mm F 1 8 G SDXC 64 MB 인화
# 정품 니콘 AF S DX NIKKOR 18 55 mm f 3 5 5 6 G VR II 벌
# 캐논 EOS 60 D 바디 병행수입 진열 DSLR 최 판매 고급 카메라 렌즈 다수 보유 관공서 납품 연중 무 24 시 친절 상담 방문 수령 가능 퀵
# 해외 13302 Nikon D 7100 DSLR Camera 18 140 mm VR DX Lens 13302 87429
# 해외 25464 Nikon D 300 SLR Digital Camera Body Only 25464 87416
# 해외 13311 Nikon D 5200 DSLR Camera 18 140 mm VR DX Lens 13311 87520
# Leica M 240 Silver M 35 mm 2 0 Silver 라이카 필터
# 캐논 정품 UV 필터 77 mm
# 4 즉시 할인 쿠폰 캐논 코리아 EOS 70 D 18 135 mm STM 싱글 렌즈
# 해외 해외 소니 Cybershot 기무사 H 400 B DSC H 400 B DSCH 400 B DSCH 400 H 400 63 x 광학 줌
# 해외 8575 B 003 Canon EOS Rebel SL 1 DSLR Camera EF S 18 55 mm 8575 B 003 87427
# 해외 06413 Pentax KS 1 DSLR Camera KS 1 Body Black 87646
# 해외 1534 Nikon D 3300 DSLR Camera 18 55 mm Lens Grey 1534 87511
# 해외 Nikon D 610 DSLR Camera Body Deluxe Kit 87573
# 해외 SLTA 99 V Sony Alpha 99 DSLR Camera Body Only SLTA 99 V 87519
# 해외 1524 Nikon D 5300 DSLR Camera 18 55 mm Lens Gray 1524 87449
# 해외 Nikon D 610 DSLR Camera Body Basic Kit 87565
# 해외 Nikon Buckmaster 3 9 x 40 Riflescope
# 컴온탑 캐논 정품 EOS 7 D Mark II BODY
# 캐논 정품 CANON EOS 7 D Mark II body 렌즈 패키지 구입 가능 견적 환영 납품 가능 조달청 대환영
# 사은 품 이벤트 JW 100 D 싱글 캐논 코리아 EOS 100 D 18 55 mm IS STM 가장 DSLR 실시간 상담
# 캐논 코리아 정품 캐논 EOS 100 D 18 55 kit 패키지 필수 구매 상품 당일 발송 방문 수령 매장 운영 싱글 렌즈
# SDHC 8 G 정품 알파 가방 인화 쿠폰 정품 소니 알파 SLT A 57 Body 소니코리아 공식 대리점 소니
# 니콘 NIKON 정품 니콘 D 7100 Body AF S 50 mm F 1 8 G SD 16 GB 포켓 융 인화 웹하드 이용권
# 5 D 완벽 가이드 책자 RC 6 무선 리모콘 호환 증정 캐논 EOS 5 D Mark III Body EF 70 200 2 8 L IS II CF 16 GB MCUV 필터 클리 너 SET 증정 품
# 정품 니콘 DSLR D 7100 BODY AF S 18 300 mm VR SD 32 GB 렌즈 인화
# 정품 니콘 DSLR D 3300 Body AF S 18 55 mm VR SD 32 GB 니콘 가방 인화
# 정품 니콘 DSLR D 3300 Body AF S 18 55 mm VR SD 32 GB 니콘 가방 인화
# 현대 카드 5 할인 3 15 캐논 EOS Hi 18 55 IS II SDHC 32 GB CL 10 UV 필터 리더 기 활용 책자 증정 품
# 캐논 정품 EOS 6 D Body 사은 품 포켓 융
# 정품 EOS 700 D KIT 18 55 IS STM 크리 닝킷 SLR 활용 책자 액정 필름 인화
# 5 만원 신세계 상품권 증정 70 D 완벽 가이드 책자 RC 6 호환 리모콘 증정 캐논 EOS 70 D Body SDHC 16 GB CL 10 리더 기 클리닝 5 종 SET 융 인화
# 캐논 CANON 정품 EOS 5 D Mark III Body EF 24 70 mm F 2 8 L II USM 정 후드 정품 전용 케이스 고급 포켓 융
# 캐논 EOS 5 D MarK III Body EF 85 mm F 1 2 L USM 정 후드 정품 전용 케이스 고급 포켓 융
# 5 만원 백화점 상품권 증정 캐논 EOS 70 D Body EF 10 18 mm F 4 5 5 6 IS STM 캐논 정품 필터 67 mm PRT 고급 포켓 융
# 삼성 카드 5 할인 20 일 단 하루 캐논 캐논 EOS 100 D 블랙 더블 렌즈 패키지 18 55 mm 40 mm KIT SD 4 GB 가방
# 5 만원 신세계 상품권 증정 전용 액정 필름 RC 6 호환 리모콘 증정 캐논 EOS 100 D 18 55 IS STM SDHC 32 GB CL 10 UV 필터 리더 기 활용 책자 증정 품
# KB 국민카드 5 할인 3 16 3 17 전용 액정 스크린 RC 6 호환 리모콘 증정 캐논 EOS 7 D Body EF 17 40 4 L CF 16 GB UV 필터 리더 기 크리 너 SET 증정 품
# 정품 캐논 EOS Hi Kit EF S 18 55 IS II SDHC 8 GB SD 리더 기 정품 전용 가방 58 mm UV 고급 포켓 융
# 정품 니콘 DSLR D 5300 Body AF S 18 55 mm VR II AF S 35 mm F 1 8 G DX 인화
# 캐논 EOS 100 D White 18 55 STM 40 2 8 STM 더블 렌즈 킷 SDHC 32 GB CL 10 UV 필터 2 매 리더 기 활용 책자 증정 품
# 캐논 EOS 6 D Body EF 24 70 mm F 2 8 L II USM
# CANON 정품 EOS 6 D BODY 40 mm f 2 8 stm 렌즈 포함 믿음 온
# RC 6 무선 리모콘 호환 증정 캐논 EOS 6 D Body SDHC 16 GB 보호 필름 융 인화
# 캐논 정품 캐논 EOS 7 D Body EF S 10 22 3 5 4 5 USM CF 16 GB UV 필터 리더 기 크리 너 SET 증정 품
# 니콘 NIKON 정품 니콘 D 7100 Body AF 18 55 mm VR SD 16 GB 니콘 스텐 다드 1 포켓 융 인화 웹하드 이용권
# 정품 니콘 DSLR D 7100 BODY 인화
# 니콘 NIKON 정품 니콘 D 7100 Body 포켓 융 인화 웹하드 이용권
# 니콘 NIKON 정품 니콘 D 7100 Body SD 16 GB 포켓 융 인화 웹하드 이용권
# 정품 니콘 DSLR D 750 Body 인화 웹하드
# 정품 니콘 D 750 Body AF S 35 mm F 1 8 G FX 용 인화
# 캐논 코리아 정품 EOS 70 D 새 제품 바디 풀 박스 인기 렌즈 필수 악 구매 정보 삼각대 DSLR 가방 메모리 등 사은 품 증정 이벤트
# 4 즉시 할인 쿠폰 정품 EOS 70 D Body 패키지 선택 가능 8 G 16 G 가방 삼각대 무선 리모콘 외 고객 만족 패키지 방문 수령
# EOS 캐논 정품 100 D 18 55 IS STM KIT 32 G 16 종 고급 패키지 FULL HD 32 G 700 배속 헤링본 정품 가방 16 종풀 패키지
# 정품 EOS 100 D KIT 18 55 IS STM 메모리 16 GB 추가 배터리 UV 필터 리더 기 캐논 정품 가방 책자 크리 닝킷 캐논 코리아 정품
# 정품 등록 시 사은 품 증정 소니 풀프레임 미러리스 알파 A 7 II K SEL 2870 표준 줌 렌즈 킷 SDHC 8 GB
# 세기 정품 시그마 SD 1 Merrill BODY 70 200 mm F 2 8 OS
# 세기 정품 시그마 SD 1 Merrill BODY 70 200 mm F 2 8 OS
# 캐논 EOS 5 D MarK III Body EF 24 105 mm F 4 L USM 정 후드 정품 전용 케이스 고급 포켓 융
# 정품 니콘 DSLR D 610 Body AF S 50 mm 1 4 G SD 32 GB 크리 닝킷 렌즈 인화
# 캐논 EOS 100 D White 18 55 STM 40 2 8 STM 더블 렌즈 킷 SDHC 8 GB CL 10 UV 필터 2 매 리더 기 활용 책자 증정 품
# 10 가지 사은 품 더블 캐논 정품 EOS 70 D 18 55 mm IS STM 55 250 mm IS 더블 렌즈 킷 Turbo 16 GB 정품 가방 멀티 코팅 필터 필름 책자 등 풀 패키지
# 이노 캐논 정품 EOS 70 D 18 55 mm IS STM 32 GB 풀 패키지 구성 렌즈 변경 가능 정품 가방 필터 삼각대 핸드 스트랩 16 종풀 패키지
# 캐논 정품 EOS HI EF S 18 55 mm IS II KIT 크리 닝 세트 SLR 활용 책자 LCD 보호 필름 웹하드 이용권 인화
# 정품 EOS HI EF S 18 55 mm IS II KIT 메모리 16 GB 리더 기 필터 헤링 본가 방 포켓 융 크리 닝 세트 SLR 활용 책자
# 정품 EOS Hi Kit EF S 18 55 IS II EF S 55 250 STM 58 UV 2 개 SDHC 16 GB C 10 SD 리더 기 No 9361
# 캐논 본사 직영 판매 EOS 700 D 더블 렌즈 기본 18 55 mm 망원 55 250 mm 패키지
# 4 즉시 할인 쿠폰 EOS EOS 700 D 팬케익 더블 렌즈 18 55 40 mm 가방 4 G
# 펜탁스 신 상품 출시 정품 펜탁스 PENTAX K S 1 Body 렌즈 포함 무료 인화
# 삼성 전자 SNT 1010
# 삼성 전자 SHR 2162 U
# DVR 씨앤 DS 2008 DH
# 신한카드 5 할인 10 일 돔 CCTV 4 DVR 패키지 DG MR 85 E 1 4 DS 7204 HVI SV 아이 컴 테크 52 만화 소주 야간 감시 적외선 1 년 무상 A S
# 아구 스 JSD 400
# watchcam DSH AF 2008
# 삼성 테크 윈 SHR 2160
# 아이 디스 IDR H 4032
# 삼성 전자 SHR 3040
# CCTV 설치 아이 디스 SDR 423 4 채널 Hull HD 960 H 120 FPS 양 방향 오디오 기능 allAV 무료 견적 서비스
# 삼성 전자 SHR 2162 U
# DVR 씨앤 DS 2008 DH
# HIKVISION DS 7204 HVI SV 960 H 4 CH 120 FPS HDMI 출력 하드 포함
# 아이 디스 SDR 1601
# 아이 디스 XDR PRO 1602
# ITX 시큐리티 SVR 5004
# 삼성 전자 SHR 5162
# 아이 디스 XDR 1600
# 나다텔 NH 0842 L
# 호남 시큐리티 이지 피스 HVR 421 S 1080 P 4 CH 3 TB
# HIKVISION DS 7204 HFHI ST 리얼타임 1080 P HD SDI 4 채널 120 FPS HDMI 출력 DVR 하드 포함
# 4 즉시 할인 쿠폰 JWC 힉비젼 DS 7216 HVI SV 16 채널 HDD 옵션 구매
# HIKVISION HD IP 4 채널 SD 4 채널 하이브리드 DVR 녹화 기 DS 7604 HI ST CCTV 설치 CCTV 설치 업체 적외선 카메라 감시카메라 CCTV 판매 CCTV 카
# DAHUA HCVR 5108 H
# 시큐 포 SENTRY 5216 16 채널 녹화 카드 CCTV DVR 감
# CCTV 자 뷰 XV 120 PCI 8 채널 120 FPS 확장 보드
# 4 즉시 할인 쿠폰 CCTV 나라 DVR 16 채널 카드 Sentry 3016 cctv 감시카메라 16 채널 240 프레임
# DVR 씨앤 DS AV 4816 DL
# DVR 씨앤 DS AV 2408 D E
# 아이티 JIKIMI 2
# GM 120 R
# 컴 자 뷰 XV 400 PCI 8 채널 확장 카드
# 씨앤비텍 BDE 1212
# 포딕스 FD 2432
# SENTRY 1104 LP 시큐 포 DVR 카드 4 채널 30 30 F CCTV 감시카메라
# 오디오 앤 케이블 MS 120 4 채널 카드 IDV 120
# 피시 포 자 뷰 XV 400 PCI 라이트 버전 DVR 카드 4 채널 30 프레임 PCI 당일 발송
# 4 즉시 할인 쿠폰 DVR 카드 자 뷰 XV 400 4 CH PCI 전문 DVR 시스템 DSP 칩 사용
# MS 120 16 채널 카드 IDV 120
# CCTV 나라 DVR 16 채널 카드 Sentry 2016 cctv 감시카메라 16 채널 120 프레임
# 엑스 시스템 자 뷰 XV 120 PCI NX 4 채널 120 120 FPS 고성능 녹화 카드 원 격감 시지
# 시큐 포 Sentry 5016 CCTV DVR 감시카메라 녹화 장치
# 시큐 포 Sentry 5416 CCTV DVR 감시카메라 녹화 장치
# Activision TE 30 카메라
# 아이디 정보 통신 MS 240 IDV 240 16 CH 카메라
# 제너시스 앤 GVR 510 카메라
# AURA 아우라 HV 2 U Plus 400 DVR 적외선 카메라 2 셋트 CCTV 감시 카메라 녹화 기 외 제품 배송 친절 상담
# 아이티엑스 엠 센트 리 1104 LP 적외선 카메라 1 개 케이블 답터 무료 CCTV 최상 A S 사은 품 증정
# 삼성 테크 윈 SDE 3002 AIO 세트 특별 할인 CCTV DVR 감시카메라 녹화 장치 CCTV 세트
# 알라딘 DVR 자 뷰 XV 400 PCI 41 만 돔 카메라 패키지 2
# 자 뷰 4 채널 XV 400 PCI CCTV DVR 카드 돔 감시카메라 4 개 케이블 어뎁터
# 삼성 테크 윈 SRD 440 적외선 카메라 2 개 set 답터 케이블 젠더 증정 CCTV 녹화 기
# 삼성 테크 윈 SDE 3002 카메라 카메라 패키지 4 채널 500 GB USB 포트 네
# 인온 삼성 테크 윈 SRD 440 돔 카메라 4 개 set 답터 케이블 젠더 증정 자가 설치 CCTV 녹화 기
# 4 즉시 할인 쿠폰 인온 CCTV 인온 삼성 테크 윈 SRD 440 적외선 카메라 3 개 set 답터 케이블 젠더 증정 CCTV 녹화 기 최상 A S 당일 출고 배송 서비스
# 후 9604 H JW 541 C 3 개 케이블 답터 HDD 500 GB 포함
# 삼성 테크 윈 SRD 440 JW 541 C 2 개 케이블 답터 HDD 포함
# 삼성 테크 윈 SRD 440 JW 541 IRD 4 개 케이블 답터 HDD 포함
# 나다텔 NH 0442 U JW 752 IRD 3 개 케이블 답터 HDD 500 GB 포함
# JWC JDR 410 JW 541 IRD 1 개 케이블 답터 HDD 500 GB 포함
# 아이 디스 CDR 410 S 돔 카메라 2 개 세트 4 채널 녹화 기 320 G 포함 500 G 변경 가능 원격지원 답터 케이블 CCTV 감시카메라 하드 용량 업그레이드 500 G 로 발송
# 4 즉시 할인 쿠폰 CCTV 알라딘 DVR 자 뷰 30 프레임 XV 400 PCI 27 만 돔 카메라 패키지 3
# 삼성 테크 윈 SRD 445 4 채널 녹화 기 1000 G 포함 스마트폰 지원 음성 녹음 CCTV 감시카메라 DVR 보안 방범 모델 SRD 445 1 T 포함 변경 습
# DVR 씨앤 DS 1004 DH
# 삼성 테크 윈 SRD 470 D
# 삼성 테크 윈 SRP 1650
# DS 7204 HVI SV
# 아이 디스 IDR 7116
# 나다텔 NVR 08 P
# 삼성 테크 윈 SRD 1680 D
# 아이 디스 PCR 7116
# DS 7216 HVI SV
# 삼성 테크 윈 SRD 840
# 삼성 테크 윈 SRD 470
# 시큐 포 SENTRY 1104
# 삼성 테크 윈 SRN 1670 D
# 삼성 테크 윈 SRD 1630 D
# JWC JDR 410 카메라
# 4 즉시 할인 쿠폰 CCTV 녹화 기 코콤 CCTV 녹화 기 8 채널 16 채널 UVR U 1600 너무 무료 배송
# 컴 자 뷰 XV 30 USB 카메라
# DS 7208 HVI SH
# 아이 디스 NDR 7932 S
# DVR 씨앤 DS 1004 DH
# 아이 디스 IDR 7116
# 삼성 테크 윈 SVR 1670
# 아이 디스 INR 1000
# 아이 디스 SDR 1641
# 삼성 테크 윈 SRD 873 D
# 아이 디스 INR 4000
# 삼성 테크 윈 SRN 1000
# 삼성 테크 윈 SVD 300
# 아이 디스 SDR 1600
# 삼성 테크 윈 SRD 1673 D
# 삼성 전자 SHR 8080
# 유 니모 UDR 7116
# 삼성 테크 윈 SVR 960
# 아이 디스 MDR 810
# 나다텔 H 0410 E
# 아이 디스 HDR 842
# 바이론 SK RP 04
# 16 포트 랙 마운트 19 인치 스위치 허브 NEXT 8316 SH
# ipTIME 16 포트 스위치 허브 SW 1600
# Manhattan LCD 모니터 거치 벽 걸이 최대 12 Kg
# 하이 언스 TV 002
# 해외 저렴 XBMC 사전 안드로이드 4 2 TV 셋톱 박스 구글 스마트 Amlogic 8726 MX 듀얼 코어 1 5 GHz 의 1 G 8 기가바이트 HDMI AV SPDIF
# 해외 구글 Chromecast 를 HDMI Mirror 2 TV 동글 TV 스틱 MHL 에어 플레이 Tronsmart T 2000 Miracast 스마트 TV 스틱 상자 DLNA
# 인사 이드 디지털 SMP 1000
# 해외 말레이시아 인도네시아 싱가포르 대만 홍콩 안드로이드 TV BoxAstro 채널 대한 1 년 IPTV 계정 APK 1 Year IPTV Account APK 안드
# 해외 TV 박스 안드로이드 4 2 Remote 제어 지원 1920 X 1080 P 3 D 출력 1 G DDR 3 4 G Allwinner A 20 인터넷 TV 셋톱 박스 New TV Bo
# 해외 안드로이드 아랍어 IPTV 버전 연간 수수료 670 아랍어 채널 아랍어 HD IPTV 상자 필요 android Arabic iptv version
# 4 즉시 할인 쿠폰 텍 Dvix 플레이어 에이 빅스 Q 10 2 8 TB
# 해외 Tronsmart T 1000 Miracast DLNA EZCAST 동글 HDMI 무선 디스플레이 TV 윈도우 맥 IOS 용 스틱 WIFI 미디어 플레이어 안드로이드
# 해외 원래 관람 석 F 5 S HD 풀 1080 p 의 S F 5 S 위성 수신기 지원 USB 무선 랜 유튜브 youpron Original Skybox F 5 S HD full 1080 p S
# 해외 1 개 원래 AZLINK HD S 1 FTA VLC 미디어 플레이어 및 DVB S 2 지원 무선 랜 PVRTurbo LS 500 8 PSK 터너 LINUX IPTV 수신기 1 pc
# 4 즉시 할인 쿠폰 Abigs 에이 빅스 Q 10 II 디빅스 플레이어 하드 포함
# 유니콘 AV A 9 안드로이드 멀티미디어 플레이어
# 해외 안드로이드 스마트 TV 박스 HDMI 무선 랜 USB SDHC
# 인파 IN HD 01
# 텍 abigs Q 3
# 이지 와이드 EZP 1080 P
# Ezcast 무선 디스플레이 답터 코시 1281
# D 외장하드 500 GB 6 4 cm 2 5 형 자개 에디 션 조각 PCD 10176
# 4 즉시 할인 쿠폰 썬텍디앤씨 크라이저 minicube X 5 USB 외 장형 세계 최초 조립 포장 출고 영상 제공
# 4 즉시 할인 쿠폰 Divx 외 장형 U 디빅스 플레이어 3 5 형 디빅스 하드 포
# USB 외 장형 COMBO ODD PCD 9216
# 모니터 컴스 GrandTec 콩 스토어
# PCD 7468 USB 3 0 외 하드 모듈 I NA 216 U 2 Plus 하드 포함 USB 3 0 외 하드 케이스 플라스틱 케이스
# 4 즉시 할인 쿠폰 G 3965 Coms 전화선 케이블 동감 김 3 M 빨강
# LI 1100 급속 충전기 18650 전용 1 알
# 국산 18650 배터리 보호 회로 내장 3
# 2 선 젤리 심선 접속 QUICK SNAP 메뚜기 100 개
# 서버 랙 12 U 블랙 LS 750 HS
# 4 즉시 할인 쿠폰 코드 프리 3 D 블루레이 codefree 플레이어 Full HD MGS 6
# PCI COMBO 카드 USB 2 0 2 1 P 1394 2 1 P
# 4 즉시 할인 쿠폰 C 디지털 미디어 플레이어 컴퓨터 주변기기 미디어 플레 정성껏 배송
# 해외 New 2014 Tronsmart T 1000 Mirror 2 TV Miracast DLNA EZCAST High Definition Multimedia Interface U
# 해외 Kasda KS 6311 BUS Android 4 2 2 Smart TV Set Top Box WI FI 150 Mbps FHD 1080 P Amlogic AML 8726 MX Du
# 넷 기어 PTVU 1000 무선 영상 전송 장치 NETGEAR Full HD 1080 p WiDi 데스크탑 노트북 HDMI DVI PC 화면 무선 대형 화면 전송
# 스트리머 FV 당일 출고 iXtreamer ice cube 무료 디빅스 플레이어
# 피시 포 유니콘 AV A 9 Divx 플레이어 USB 호스팅
# USB 2 0 5 포트 PCI 확장 카드 NEC 칩셋 NEXT 205 NEC
# 5 즉시 할인 해외 직 배송 Western Digital WD TV Live Media Player Wi fi 1080 p 40073024
# MC 35 L 스피곳 폰 마운트 자전거 거치 스마트폰 거치
# 텍 DivX 플레이어 abigs Q 10 II 8 TB DST
# 4 즉시 할인 쿠폰 당일 출고 유니콘 AV A 9 안드로이드 셋톱 디빅스 플레이어 AV A 9 하나 스마트 TV 로 OK
# 해외 DLNA 에어 플레이 Miracast Ipush SPC 3699 대한 와이파이 동글 HDMI 디스플레이 TV 무선 수신기 WiFi Dongle HDMI Display TV
# 해외 말레이시아 애스 채널 IP 9000 APKMalaysia 천체 채널 다른 홍콩 대만 본토 245 HD 라이브 채널 지원 Malaysia astro channels
# 해외 안드로이드 TV 박스 12 개월 말레이시아 APK 계정 작업 말레이시아 인도네시아 싱가포르 브루나이 천체 전체 채널 지원 12 months Malaysia APK Ac
# 모바일 넷 MS 220 안드로이드 멀티미디어 플레이어
# 해외 풀 HD 1080 p 의 Dreamlink HD 디지털 위성 수신기 지원 무선 랜 SK 200 ATSC 8 QPSK 북미 Full HD 1080 p Dreamlink HD Di
# 4 즉시 할인 쿠폰 Abigs 텍 Dvix 플레이어 에이 빅스 Q 10 2 6 TB 당일 출고 방문 수령 퀵서비스 가능
# 4 즉시 할인 쿠폰 해외 HELLO KITTY KT 2053 Alarm Clock Radio CD Player
# 해외 2014 ipremium 의 IPTV 상자 라이브 TV 스카이 Sports 1 HD BT 스포츠 1 은 EPL FA 컵 유로파 리그 분데스리가 볼 수 2014
# 해외 20 PCS 원래 관람 석 F 3 S HD 1080 p 풀 관람 석 F 3 S 위성 수신기 지원 USB 무선 랜 유튜브 youpron 20 pcs lot Original Skybo
# 아이티 엔조이 텍 Abigs 에이 빅스 Q 10 2 6 TB 포장 출고 동영상 제공
# 4 즉시 할인 쿠폰 유니콘 AV A 9 안드로이드 셋톱 디빅스 플레이어 FV AV A 9 하나 스마트 TV 로 OK
# 해외 M 2 EZCast DLNA 멀티미디어 Miracast AirPlay 를 스크린 TV 와이파이 HDMI 동글 수신기
# 밸류 플러스 TizzBird N 1
# 지넷 유비쿼터스 넥스트 NEXT MTV 200
# dvix 플레이어 UNICORN 콩 스토어
# K WiFi 도킹 스테이션 USB 3 0 PCD 9394
# PCD 9114 하드 도킹 스테이션 3500 ES eSATA USB 2 0 6 4 cm 8 9 cm 3 5 인치 2 5 인치 S ATA 하드 USB 2 0 eSATA 통 알루미늄
# 해외 GoogleGoogle Chromecast HDMI Streaming Media Player
# ipTIME 공유기 NAS I NAS 3 5 인치 1 베이 HDD 탑재 기가비트 유선 PCD 0563
# 컴퓨터 주변기기 컴스 GrandTec 콩 스토어
# PCD 7468 USB 3 0 외 하드 모듈 I NA 216 U 2 Plus 하드 포함 USB 3 0 외 하드 케이스 플라스틱 케이스
# USB 외 장형 DVD MULTI ODD PCD 9217
# LI 1100 급속 충전기 18650 전용 1 알
# 카메라 렌즈 UV 필터 사이즈 선택
# 국산 18650 배터리 보호 회로 내장 3
# Coms USB 수동 선택 기 4 1 제품 A 타입 4 포트 B 타입 1 포트
# 4 즉시 할인 쿠폰 C HDD 케이스 3 5 인치 폴더 접이식 색상 Black
# 해외 WD 본사 직송 WD TV Live Streaming Media Player
# Coms KVM USB 스위치 4 1
# 4 즉시 할인 쿠폰 C 디지털 미디어 플레이어 컴퓨터 주변기기 미디어 플레 정성껏 배송
# Coms LCD 모니터 거치 벽 걸이 최대 18 Kg Tilt 조절 가능
# 해외 New Arrival 1080 P Multi media Dongle TV box Receiver PTV Pro Miracast DLNA Airplay 2 4 G 5 G WIFI
# 듀얼코어 스마트 TV VGA 출력 지원 카멜 안드로이드 셋톱박스 ATV 1000
# FV 당일 출고 iXtreamer ice cube 무료 디빅스 플레이어
# 코드 프리 DVD 필립스 정품 DVP 2899 yun 96 wp 5 code free region free 세계 모든 DVD 재생 NTSC PAL 방식 재생 MULTI DVD HDMI 1080 업 스케일
# Coms LCD 거치 DL 084 F Two arm
# 유니콘 Xtreamer
# 158045 NEXT 넥스트 무선 멀티미디어 디스플레이 HDMI 지원 NEXT MTV 300
# 해외 Nagrace HPH 안드로이드 TV BOXRK 3288 2 G 16 G 플래시 지원 4 K 2 K Nagrace HPH 안드로이드 TV BOXRK 3288 2 G 16 G FLASH Sup
# 모뉴 MoPix 300 DA
# 해외 라틴 미국인 Spanishes 멕시코 인 안드로이드 4 2 2 TV BoxAmlogic 듀얼 CoreWifi XBMC 대한 2014 무료 XBTV 라이브 The 20
# 해외 4 개 최신 아랍어 IPTV 상자 무료 시청 2 년 지원 620 플러스 아랍어 channelsBeinSports loolbox 4 pcs lot Newest Ara
# 해외 2014 1080 P HST BOX 아랍어 IPTV 2014 New 1080 P HST BOX Arabic IPTV
# 해외 Tronfy RK 3288 쿼드 코어 코어 텍스 A 17 4 K 안드로이드 4 4 2 G 8 기가바이트 TV BOX UBOXWiFi HDMI XBMC 블루투스 4 0
# 해외 안정 성능 원래 관람 석 F 5 S HD 1080 p 풀 위성 수신기 지원 USB 무선 랜 유튜브 youpron Free shipping Stable Performanc
# 해외 지정 웹 사이트 독점 아랍어 IPTV 인도 IPTV 영어 IPTV 320 Channels 통해 아프리카 IPTV 의 4 IN 1 The specified website
# 해외 700 무료 channelsBein 스포 츠 OSN MBC 아랍어 TV 박스 제조 업체 700 free channelsBein sport OSN MBC arabic
# 유니콘 Xtreamer Ultra
# 해외 유로 Libertview F 5 S 풀 HD 1080 P 디코더 지원 cccam 관람 석 F 5 위성 수용체 2014 2014 Vision Libertview
# 해외 HD 미디어 플레이어 1920 x 1080 p DVB T 2 Andorid 4 2 AML 8726 MX 듀얼 코어 HDMI WIFI T 2 TV Receicer 3 D AV 스마트 안드
# 해외 풀 HD 1080 P DVB T 2 TV 셋톱 박스 디지털 지상파 ReceiverUSB HDMI 인터페이스 지원 MPEG 4 H 264 Full HD 1080 P DVB
# 필립스 DVP 2880 K HDMI 2013 년 DVD 플레이어 CinemaPlus HDMI 1080 P USB 인식 DivX 재 총알 배송 다운로드 이용권 증정
# Sh air TV N 1
# 유니콘 iXtreamer
# 하이 언스 New TV 001
# 씨게이트 2 TB 7200 RPM 64 M ST 2000 DM 001
# 씨게이트 500 GB 5400 RPM 16 MB ST 500 LT 012
# 도시바 1 TB 7200 RPM 32 MB DT 01 ACA 100
# 250 GB 7200 RPM 16 M WD 2500 AAKX
# 2 TB 5400 RPM 64 MB WD 20 EARS
# RED 4 TB WD 40 EFRX NAS HDD 5400 RPM
# 씨게이트 SV 35 HDD Rescue 3 TB 7200 RPM 64 MB ST 3000 VX 004
# 1 TB 5400 RPM 64 MB Purple WD 10 PURX
# 씨게이트 160 G 7200 RPM 2 M ST 3160215 A
# 씨게이트 1 TB 7200 RPM 128 MB ST 1000 NM 0033
# 히타치 1 TB 7200 RPM 32 MB HUA 722010 CLA 330
# 320 GB 7200 RPM 16 MB WD 3200 AAKX
# 씨게이트 Desktop SSHD 4 TB ST 4000 DX 001
# 250 GB 10000 RPM 64 MB WD 2500 HHTZ
# 320 GB 7200 RPM 16 MB WD 3200 AAKS
# 씨게이트 500 GB 7200 RPM 32 MB ST 3500320 AS
# 씨게이트 500 GB 7200 RPM 16 MB ST 9500420 AS
# 4 즉시 할인 쿠폰 SATA 80 G 250 G 데스크탑 용 하드디스크 시게이트
# 삼성 전자 250 GB 7200 RPM 8 MB SP 2504 C
# 씨게이트 2 TB 7200 RPM 128 MB ST 2000 NM 0053
# 4 즉시 할인 쿠폰 현대 Hmall TG 삼보 외장하드 래피드 미러 TG RM 25 SS 320 GB
# 4 즉시 할인 쿠폰 히타치 HGST DESKSTAR IDK DC 4 TB 64 MB HDS 724040 ALE 640 하드디스크 3 5 7200 rpm SATA 3
# 시게이트 MK 씨게이트 Seagate 서버 용 NAS HDD 컨스텔 레이 션 ES 3 SED 기술 탑제 S ATA 3 2 T 128 M ST 2000 NM 0053 무상 AS 5 년
# 신한카드 5 할인 3 13 시게이트 NAS 서버 용 3 5 형 HDD 컨스텔 레이 션 CS SATA 3 2 TB 64 MB 7200 RPM ST 2000 NC 001
# 4 즉시 할인 쿠폰 현대 Hmall TG 삼보 외장하드 TG RN 35 SS 500 GB
# 4 즉시 할인 쿠폰 구매 대행 해외 직 배송 하드디스크 WD AV GP 320 GB AV Hard Drive 3 5 Inch SATA II 16 MB Cache WD 3200 A
# 해외 Micro SATA Cables Micro SATA 1 8 Inch Drive 2 5 Inch Laptop Drive Caddy 2047266
# 해외 Dell 146 GB 2 5 Hard Drive Internal 2047153
# 4 즉시 할인 쿠폰 구매 대행 해외 직 배송 하드디스크 HDS 721075 KLA 330 PN 0 A 36194 MLC BA 2635 Hitachi 750 GB SATA 3 5 Hard Dr
# 4 즉시 할인 쿠폰 구매 대행 해외 직 배송 하드디스크 WD Red 3 TB NAS Hard Drive 3 5 Inch SATA III 64 MB Cache WD 30 EFRX
# 4 즉시 할인 쿠폰 구매 대행 해외 직 배송 하드디스크 HGST Deskstar 3 TB 3 5 Inch 7200 RPM SATA III 6 Gbps 64 MB Cache Internal
# 4 즉시 할인 쿠폰 iclub Blue SATA 3 500 GB 16 MB WD 5000 AAKX A S 무상 2 년
# 5 즉시 할인 쿠폰 새 상품 HDD 스콜 피오 블랙 SATA 2 320 G 500 G 선택 새 상품 배송
# 4 즉시 할인 쿠폰 Seagate 1 TB Desktop SSHD ST 1000 DX 001 당일 배송 바로 출발 정품 새 제품
# 4 즉시 할인 쿠폰 해외 세금 포함 일본 정품 I O DATA PS 4 동작 확인 AdvertiseMessage 입력
# 4 즉시 할인 쿠폰 HGST 구 히타치 히타치 SATA 2 500 GB Travelstar
# 4 즉시 할인 쿠폰 WD 명 정보 Recertified WD 7500 BPVT SATA 3 750 GB
# 히타치 500 GB 7200 RPM 16 MB HTS 725050 A 9 A 364
# 4 즉시 할인 쿠폰 Seagate SATA 3 4 TB 64 MB ST 4000 DM 000 A S 무상 2 년
# 4 즉시 할인 쿠폰 Seagate 3 TB Surveillance HDD Rescue ST 3000 VX 005
# 4 즉시 할인 쿠폰 히타치 HGST DESKSTAR IDK Coolspin 4 TB 32 MB HMS 5 C 4040 A
# HGST DESKSTAR IDK Coolspin 4 TB 32 MB HMS 5 C 4040 ALE 640 하드디스크 3 5 데스크탑 NAS HDD 5700 rpm SATA 3
# 시게이트 NAS 서버 용 HDD 컨스텔 레이 션 ES 3 SAS 4 TB ST 4000 NM 0023
# 4 즉시 할인 쿠폰 HGST DESKSTAR IDK Coolspin 4 TB 32 MB HMS 5 C 4040 ALE 640 3 5 데스크탑 NAS HDD 5700 rpm SA
# 3 5 형 128 MB 7200 RPM SATA 3 네트워크 하드 시게이트 기업 용 NAS HDD EnterPrise NAS 3 TB ST 3000 VN 0001
# HGST 하드디스크 DESKSTAR NAS 3 TB 64 MB HDN 724030 ALE 640 3 5 데스크탑 NAS HDD 7200 rpm SATA 3 소음
# HGST DESKSTAR NAS 3 TB 64 MB HDN 724030 ALE 640 하드 3 5 데스크탑 NAS HDD 7200 rpm SATA 3
# 4 즉시 할인 쿠폰 히타치 HGST DESKSTAR NAS 3 TB 64 MB BOX 정품 HDN 724030 ALE 640
# AK 히타치 HITACHI HGST DESKSTAR NAS 3 TB 64 MB BOX 정품 HDN 724030 ALE 640 BOX 3 년 하드디스크 3 5 데스크탑 NAS
# HGST DESKSTAR NAS 3 TB 64 MB BOX 정품 HDN 724030 ALE 640 BOX 3 년 하드디스크 3 5 데스크탑 NAS HDD 7200 rpm S
# HGST 하드 DESKSTAR NAS 3 TB 64 MB BOX 정품 HDN 724030 ALE 640 BOX 3 년
# 1 주년 이벤트 Hitachi HGST 6 TB Ultrastar 7 K 6000 HUS 726060 ALE 614 SATA 3 7200 128 M
# 아이디 존 Hitachi HGST 6 TB Ultrastar 7 K 6000 HUS 726060 ALE 614 SATA 3 7200 128 M 기업 아이디 존
# ECOPC 당일 출고 새 제품 정품 Hitachi HGST 6 TB Ultrastar 7 K 6000 HUS 726060 ALE 614 SATA 3 7200 128 M
# Z HGST HITACHI 6 TB 기업 용 HDD 3 5 인치 S ATA 3 HUS 726060 ALE 614 Ultrastar 7 K 6000 기업 서버 고급 사용자 용 ISE SED
# 씨게이트 NAS 서버 용 3 5 형 HDD 컨스텔 레이 션 ES 3 SATA 3 4 TB 128 MB 7200 RPM ST 4000 NM 0033
# AK 씨게이트 시게이트 NAS 서버 용 3 5 형 HDD 컨스텔 레이 션 ES 3 SAS 1 TB 128 MB 7200 RPM ST 1000 NM 0023
# 씨게이트 NAS 서버 용 3 5 형 HDD 컨스텔 레이 션 ES 3 SATA 3 2 TB 128 MB 7200 RPM ST 2000 NM 0033
# Seagate NAS 서버 용 3 5 형 HDD 컨스텔 레이 션 ES 3 SATA 3 2 TB 128 MB 7200 RPM ST 2000 NM 0033
# 시게이트 MK 씨게이트 Seagate 서버 용 NAS HDD 컨스텔 레이 션 ES 3 SATA 3 2 T 128 M ST 2000 NM 0033 무상 AS 5 년
# 시게이트 MK 씨게이트 Seagate 서버 용 NAS HDD 컨스텔 레이 션 ES 3 SATA 3 2 T 128 M ST 2000 NM 0033 무상 AS 5 년
# 트랜센드 트랜샌드 Transcend JetDrive Lite 360 64 GB TS 64 GJDL 360
# 삼성 카드 5 할인 15 일 트랜샌드 Transcend JetDrive Lite 360 64 GB TS 64 GJDL 360
# 해외 구매 대행 B 00 MANO 6 CI WD 7501 AALS 75 J 7 B 0 2061 701567 400 AD WD SATA 3 5 PCB
# 4 즉시 할인 쿠폰 HGST DESKSTAR NAS 5 TB 128 MB BOX 정품 HDN 726050 ALE 610 BOX 3 년 하드 데스크탑 NAS HDD 7200 rpm
# 해외 New HP StorageWorks D 2700 2 TB 7 2 K SATA 2 5 quot Hard Drive 1 Year Warranty
# 해외 WD WD 3200 JS 320 GB 7200 RPM 3 5 8 MB SATA HD Like New
# 해외 White Label 120 GB 8 MB Cache 7200 RPM PATA IDE 3 5 quot Desktop Hard Drive w 1 Year Warranty
# 해외 White Label White Label 120 GB 8 MB Cache 7200 RPM PATA IDE 3 5 Desktop Hard Drive w 1 Year Warra
# 해외 구매 대행 B 002 P 3 KO 4 W WESTERN HDD 80 GB 7200 RPM PATA 8 MB WD 800 AAJB
# Hitachi 3 TB Ultrastar 7 K 4000 HUS 724030 ALA 640 SATA 3 7200 64 M
# 공인 판매점 단골 우대 Hitachi 3 TB Ultrastar 7 K 4000 HUS 724030 ALA 640 SATA 3 7200 64 M
# 리뷰 안 SSD microSATA 128 GB mcSATA 850
# 3 5 형 128 MB 7200 RPM SATA 3 네트워크 하드 시게이트 기업 용 NAS HDD EnterPrise NAS 6 TB ST 6000 VN 0001
# 공인 판매점 단골 우대 Hitachi 4 TB Ultrastar 7 K 4000 HUS 724040 ALA 640 SATA 3 7200 64 M
# 4 즉시 할인 쿠폰 ERR HGST 4 TB Ultrastar 7 K 4000 HUS 724040 ALA 640
# 3 5 형 128 MB 7200 RPM SATA 3 데이터 복구 기능 시게이트 기업 용 NAS HDD EnterPrise NAS Rescue 3 TB ST 3000 VN 0011
# 4 즉시 할인 쿠폰 히타치 HGST 2 5 서버 용 하드 Ultrastar C 15 K 600 300 GB HDD HUC 15
# HGST 2 5 하드 Ultrastar C 15 K 600 300 GB HDD HUC 156030 CSS 200
# 3 5 형 128 MB 7200 RPM SATA 3 네트워크 하드 시게이트 기업 용 NAS HDD EnterPrise NAS 2 TB ST 2000 VN 0001
# HGST DeskStar IDK DC 4 TB HDS 724040 ALE 640 3 5 인치 7200 rpm NAS 서버 고급 사용자 용 HDD 정품 박스 무상 AS 3 년 상품권 보조 배터리 증정
# 히타치 HGST DESKSTAR IDK DC 4 TB 64 MB BOX 정품 HDS 724040 ALE 640 BOX 3 년 3 5 데스크탑 NAS HDD 7200 rpm
# Z 무상 AS 3 년 박스 정품 HGST DeskStar IDK DC 4 TB HDS 724040 ALE 640 3 5 인치 7200 rpm NAS 서버 HDD 제타
# Seagate NAS 서버 용 3 5 형 HDD 컨스텔 레이 션 CS SATA 3 3 TB 64 MB 7200 RPM ST 3000 NC 002
# 씨게이트 씨게이트 공식 총판 대원 CTS Seagate Barracuda HDD 500 GB ST 500 DM 002 데스크탑 용 SATA 3 7200 RPM 16 MB
# 시게이트 데스크탑 용 하이브리드 SSHD 2 TERA ST 2000 DX 001 7200 RPM 8 Gb SSHD SATA 3 64 M
# HITACHI HGST 울트라 스타 7 K 4000 SATA 3 4 TB HDD HUS 724040 ALE 640 7200 RPM 6 Gb 64 MB 3 5 형 전력 저
# 히타치 울트라 스타 HUS 724040 ALE 640 SATAlll 7 K 4000 4 TB 하드디스크 HDD 7200 rpm 64 M HDD PC 용 SATA 3 6 Gb 4 TB
# HGST Ultrastar C 15 K 600 HUC 156060 CSS 200 600 GB 2 5 인치 기업 용 SAS 드라이브 128 MB 12 Gb SAS ISE 특수 보안 삭제 SED 자체 암호
# 시게이트 NAS 서버 용 HDD 컨스텔 레이 션 CS SATA 3 4 TB ST 4000 NC 001
# IT 카드 3 포장 출고 동영상 제공 Seagate 2 TB Enterprise NAS ST 2000 VN 0001 SATA 3 7200 128 M 당일
# 2 TB Enterprise NAS ST 2000 VN 0001 SATA 3 7200 128 M
# Seagate EnterPrise NAS 2 TB ST 2000 VN 0001 기업 NAS 전문 가용 HDD 7200 rpm 128 MB RV 센서 3 D 모터 밸 런싱 적용 듀얼 스테이지 액츄이터
# 씨게이트 SV 35 Rescue ST 2000 VX 004 2 TB 하드디스크 SATA 3 7200 RPM 64 MB 사은 품 선착순 300 명 응급 구급 키트 1 1 증정
# IW Seagate 2 TB SV 35 Rescue ST 2000 VX 004 SATA 3 64 MB
# 데이터 무료 복구 2 TB SV 35 Rescue HDD ST 2000 VX 004
# IT 카드 3 포장 출고 동영상 제공 Seagate 6 TB Enterprise NAS ST 6000 VN 0001 SATA 3 7200 128 M 당일
# BNB Seagate 6 TB Enterprise NAS HDD ST 6000 VN 0001 SATA 3 7
# Seagate EnterPrise NAS 6 TB ST 6000 VN 0001 기업 NAS 용 7200 rpm 128 MB MTBF 1 기업 NAS 프로 유저 단 하나 선택
# 씨게이트 씨게이트 Surveillance ST 6000 VX 0011 Rescue 6 TB
# 플렉스 G 플렉스 2 KT 신규 32 G G 플렉스 2 플렉스 2 LG F 510 K 요금 제 자유 부가 KT 공식 인증 가입 센터 당일 발송 처리
# DSPN KT LG 전자 번호 이동 보상 기변 LG G 3 Beat LG F 470 K 원 0 원 순 완전 무한 99 가입 비 분납 유심 비후납 위약금 부가 서비스 면제
# KT 신규가입 약정 24 개월 SM N 916 K 갤럭시 노트 4 S 할부 원금 612000 원 요금 제 순 완전 무한 99 가입 비 분납 유심 비후납 위약금 부가 서비스
# CJ 번호 이동 브 리즈 P 2100 24 개월 할부 원금 0 원 헬로 표준 가입 비 분납 유심 후납 위약금 할인 반환 금 공시 원금 부가
# KT 엑스페리아 C 3 XPR C 3 번호 이동 순 41 요금 제 할부 원금 1 원 24 개월 약정 가입 비 분납 유심 비후납 부가 서비스 최대 위약금 배송
# KT 번호 이동 24 개월 약정 SHV E 310 K 16 G 갤럭시 메 1 원 LTE 1000 가입 비 분납 유심 비후납 부가 서비스 할인 반환 금 적용 최고급 사은 품 제공
# 팬택 베가 IM A 810 K 16 G Vega LTE M 기기 변경
# CJ 기기 변경 갤럭시 노트 3 SM N 900 K 24 개월 할부 원금 257 000 원 LTE 62 가입 비 면제 유심 면제 위약금 할인 반환 금 공시 원금 부가
# 갤럭시 노트 엣지 SM N 915 K 24 개월 할부 원금 716 000 원 가입 비 면제 유심 후납 위약금 지원 금 부가 순 완전 무한 99 KT 기기 변경
# KT 신규가입 SHV E 310 K 갤럭시 메 할부 원금 1 원 완전 무한 129 기준 가입 비 면제 유심 후납 부가 할인 반환 금 최고급 프리미엄 사은 품 제공 무료 배송 당일 발송 전
# 팬택 브 리즈 4 P 2100 번호 이동
# CJ 번호 이동 G 프로 2 LG F 350 K 24 개월 할부 원금 454 700 원 LTE 62 가입 비 분납 유심 후납 위약금 할인 반환 금 공시 원금 부가
# 해외 KT 결합 무 이자 할인 쿠폰 KT 결합 상품 HTC ONE M 8 16 GB LTE 골드
# KT 보상 기변 24 개월 AIP 6 64 G 아이폰 6 64 G 665 250 순완무 99 기준 가입 비 분납 유심 비 후납 할인 반환 금 부가 서비스
# 해외 KT BYBLE olleh 블랙베리 패스포트 SQW 100 1 32 GB LTE 화이트
# 소니 엑스페리아 D 2105 4 G Xperia E 1 dual 번호 이동
# KT 보상 기변 24 개월 AIP 6 P 64 G 아이폰 6 플러스 64 G 791 500 순완무 99 기준 가입 비 면제 유심 비 후납 할인 반환 금 부가 서비스
# 해외 KT 결합 무 이자 할인 쿠폰 KT 결합 상품 소니 엑스페리아 J ST 26 4 GB 3 G 블랙
# 애니콜 CJ 온라인 공식 가입 센터 기본 료 9000 기기 값 0 원 할부 0 원 효도 폰 와인 샤베트 미니 폴더 노리 폴더 2 요금 자유
# 삼성 전자 SM A 500 K Galaxy A 5 번호 이동
# 삼성 전자 SM A 700 K Galaxy A 7 기기 변경
# 애플 AIP 6 P 64 G iPhone 6 Plus 기기 변경
# LG 전자 LG 모바일 LG F 320 K 32 G G 2 번호 이동
# 팬택 베가 IM A 890 K 32 G VEGA 시크릿 노트 기기 변경
# LG 전자 LG F 510 K G Flex 2 번호 이동
# 삼성 전자 SM G 850 K 32 G Galaxy Alpha 신규가입
# 삼성 전자 SM N 916 K Galaxy Note 4 S LTE 신규가입
# LG 전자 LG F 460 K 32 G G 3 cat 6 번호 이동
# 팬택 베가 IM A 900 K VEGA 시크릿 업 번호 이동
# 팬택 베가 IM A 910 K VEGA IRON 2 기기 변경
# 삼성 전자 갤럭시 SHV E 310 K 16 G GALAXY MEGA 신규가입
# LG 전자 옵티머스 LG F 220 K 16 G Optimus GK 기기 변경
# 엑스페리아 올레 소니 엑스페리아 Z 1 XPR Z 1 기변
# 에이서 Liquid Z 5 4 G Z 150 번호 이동
# 갤럭시 그랜드 맥스 KT 신규 16 G KT 신규가입 24 개월 약정 SM G 720 NO 28 요금 제 가입 비 분납 유심 후납 위약금 약정 4 부가
# 해외 KT 결합 무 이자 할인 쿠폰 영문 각인 블랙베리 클래식 Q 20 SQC 100 1 16 GB LTE 블랙
# KT 번호 이동 24 개월 약정 SM A 700 K 할부 285 200 원 가입 비 분납 유심 후납 34 요금 제 위약금 약정 4 부가 삼성 갤럭시 A 7 폰
# LG 전자 옵티머스 LG F 200 K 16 G Optimus Vu II 기기 변경
# 엑스페리아 CJ 헬로 번호 이동 엑스페리아 Z 3 콤팩트 무한 수다 55 원 249 000 원 해지 위약금 300 000 원
# KT 번호 이동 24 개월 약정 SM A 500 K 할부 186 200 원 가입 비 분납 유심 후납 34 요금 제 위약금 약정 4 부가 삼성 갤럭시 A 5 폰
# KT 신규가입 약정 24 개월 XPR C 3 엑스페리아 C 3 할부 원금 1 원 요금 제 완전 무한 129 가입 비 분납 유심 비후납 할인 반환 금 적용 부가 서비스
# KT 번호 이동 아이폰 6 플러스 16 G AIP 6 P 16 24 개월 할부 원금 622 650 원 순 완전 무한 77 가입 비 분납 유심 후납 위약금 공시 원금 부가
# 아이폰 6 Plus 16 G 622 700 원 순 완전 무한 99 가입 비 분납 유심 후납 부가 2 년 약정 할인 반환 금 지원 반환 금 AIP 6 P 16 KT 번호 이동
# KT 보상 기변 24 개월 약정 갤럭시 노트 3 네오 SM N 750 K 할부 원금 291 300 원 순 완전 무한 99 기준 가입 비 면제 유심 후납 할인 반환 금 적용 부가 서비스 면제
# KT 번호 이동 G 플렉스 LG F 340 K 할부 원금 454 700 원 약정 24 개월 순 완전 무한 99 가입 비 분납 유심 후납 할인 반환 금 지원 반환 금 부가 서비스
# KT 기기 변경 갤럭시 코어 SHW M 585 D 24 개월 할부 원금 0 원 순 완전 무한 77 가입 비 면제 유심 면제 위약금 공시 원금 부가
# 갤럭시 코어 0 원 순 완전 무한 99 가입 비 면제 유심 후납 2 년 약정 할인 반환 금 지원 반환 금 SHW M 585 D KT 기기 변경
# KT 번호 이동 24 개월 약정 갤럭시 S 5 광대역 LTE A SM G 906 K 할부 원금 391 400 원 순 완전 무한 99 기준 가입 비 분납 유심 후납 할인 반환 금 적용 부가 서비스 면제
# 6 즉시 할인 쿠폰 2 포트 USB KVM 스위치
# 4 즉시 할인 쿠폰 ATEN 8 1 PS 2 랙 타입 KVM 스위치
# 6 즉시 할인 쿠폰 ATEN CS 1744 4 포트 USB 듀얼 뷰 KVMP 스위치 CS 1744
# 6 즉시 할인 쿠폰 ATEN VS 881 8 포트 비디오 스위치 VS 881 General VGA
# 6 즉시 할인 쿠폰 ATEN VS 881 8 포트 비디오 스위치 VS 881 General VGA
# 6 즉시 할인 쿠폰 ATEN CE 770 USB KVM 연장 기 CE 770 USB KVM Extender
# 6 즉시 할인 쿠폰 ATEN CL 5708 8 포트 Slideaway 17 LCD KVMP 스위
# 6 즉시 할인 쿠폰 ATEN CS 1754 4 포트 PS 2 USB KVM 스위치 CS 1754 USB
# 6 즉시 할인 쿠폰 ATEN CL 1016 16 포트 Slideaway LCD KVM 스위치 CL 1
# 6 즉시 할인 쿠폰 2 포트 PS 2 KVM 스위치 KVM 스위치 2 1 케이블 포함 PS 2 P
# KW PS 2 타입 Mix 8 1 KVM 스위치 OSD 전용 케이블
# 6 즉시 할인 쿠폰 NETmate KVM 4 1 스위치 마우스 클릭 킹 K
# 4 즉시 할인 쿠폰 ATEN CS 72 U USB 포트
# ATEN CE 350 PS 2 KVM 연장 기 CE 350 PS 2 KVM Extender
# 6 즉시 할인 쿠폰 NETmate USB KVM 2 1 스위치 IC 1612 U
# US 224 ATEN 2 포트 USB 주변 공유 장치 US 224
# AVC 593 KVM 스위치 2 1 PS 2 형
# 6 즉시 할인 쿠폰 ATEN CS 231 컴퓨터 공유 디바이스 CS 231 PC Sharing
# 6 즉시 할인 쿠폰 ATEN CS 1742 2 포트 USB 듀얼 뷰 KVMP 스위치 CS 1742
# 6 즉시 할인 쿠폰 ATEN CS 231 컴퓨터 공유 디바이스 CS 231 PC Sharing
# 6 즉시 할인 쿠폰 PCDNETmate DVI KVM 2 1 스위치 네트워크 KVM 서버 콘
# ATEN CS 62 S USB 포트 PCP 0001
# 6 즉시 할인 쿠폰 DA KVM 연장 케이블 10 M
# 6 즉시 할인 쿠폰 오 피트 IEEE 1394 광 케이블 리피터 40 M
# 콕 8 포트 PS 2 랙 타입 KVM 스위치 KVM 스위치 8 1 PS 2 케이블 포함 최대 해상도 1920 X 1440 전원 답타 포함 랙 마운 배송
# 4 즉시 할인 쿠폰 KW CAT 5 USB KVM 8 1 스위치
# ATEN CS 62 A USB 포트 PCP 0002
# NETmate KVM 21 스위치 PCD 0976
# NETmate 일체 USB KVM 21 스위치 PCD 0994
# 6 즉시 할인 쿠폰 유니 클래스 4 1 USB KVM 스위치 AH 04 안전 배송 상담 배송 철처 A S
# ATEN CS 72 E USB 포트
# 6 즉시 할인 쿠폰 ATEN VS 0202 2 포트 비디오 매트릭스 스위치 2 입력
# NETmate KVM 41 스위치 PCD 0978
# 6 즉시 할인 쿠폰 NETmate KVM 2 1 스위치
# 4 즉시 할인 쿠폰 ATEN 랩탑 USB KVM 스위치
# KB 국민카드 5 할인 3 14 ATEN CL 1316 N 16 포트 48 cm LCD KVM 스위치 RGB 연결 Slideaway LCD KVM 스위치 랙 착
# KB 국민카드 5 할인 13 일 유니콘 UA 116 OK 16 포트 KVM 스위치 OSD 기능 다중 컴퓨터 제어 컴퓨터 수동 선택 기
# UA 116 OK KVM 스위치 16 포트 허브 Hot Key 기
# 알파 유니콘 UA 116 OK KVM 스위치 케이블 분리 연결 16 단자 PS 2 2 개 D Sub 배송
# 6 즉시 할인 쿠폰 근호 유니콘 UA 116 OK
# 19 세미 판매 금지 라스 맥 LB 11 터치 펜 볼펜 겸용 레이저 포인터 3 1
# 4 즉시 할인 쿠폰 ATEN CS 1316 16 포트 PS 2 USB 포트 KVM 스위치 RGB 연결 고해 도지원 2048 x 1536 오토 스캔 랙 탑재 가능
# GL DGU 01 NETmate CAT 5 KVM 스위치 USB Dongle
# PCD NETmate CAT 5 KVM 스위치 USB Dongle
# NETmate CAT 5 KVM 스위치 USB Dongle DGU 01
# PCD 1032 NETmate CAT 5 KVM 스위치 USB Dongle KVM 스위치
# NETmate PS 2 USB 듀얼 콘솔 COMBO KVM 16 2 스위치 OSD CASCADE 컴퓨터 용품 유무 공유기 컴퓨터 주변기기
# NETmate IC 814 IW 4 1 KVM 스위치 케이블 포함 RGB PS 2 타입 모니터 키 보드 마우스
# 라인 IPTIME N 150 UA SOLO USB 안테나 무선랜 카드 무선 150 Mbps 무선 공유기 AP 모드 Ad Hoc 모드 WPS 무상 AS 1 년
# 6 즉시 할인 쿠폰 동 NETmate 넷 메이트 스위처 KVM 2 1 스위치 PS 2 미니 OC 22 PS 2 타입 KVM 스위치 2 1
# NETmate KVM 2 1 스위치 PS 2 미니 컴퓨터 용품 무선 공유기 유선 공유기 공유기 컴퓨터 주변기기 유무 선공 유기
# KB 국민카드 5 할인 3 16 3 17 ATEN CS 1732 A 2 포트 RGB 연결 음원 포트 탑재 USB 포트 주변기기 연결 KVMP 스위치
# 4 즉시 할인 쿠폰 ATEN CS 1754 4 포트 RGB 연결 PS 2 USB KVM 스위치 랙 착 가능
# G 7435 KVM 스위치 4 포트 PS 2 방식
# NETmate Slim KVM 연장 RGB 케이블 7 M PCD 1041
# CL 5716 16 포트 Slideaway 17 LCD KVMP 스위치 CL 5716 17 19 inch LCD KVM Switc 제품 정성 배송
# 6 즉시 할인 쿠폰 PCD NX 98 V 모니터 배기 8 포트 DSUB 15 P 8 분배 기 25
# 6 즉시 할인 쿠폰 ATEN CS 1316 8 16 포트 PS 2 USB 랙 타입 KVM 스위치 C
# 6 즉시 할인 쿠폰 2 포트 PS 2 KVM 스위치 이베이 용 DVI KVM 스위치 케
# 6 즉시 할인 쿠폰 NETmate Slim KVM 연장 RGB 케이블 7 M
# 6 즉시 할인 쿠폰 DA KVM M M 케이블 3 M 5 M 택일
# 6 즉시 할인 쿠폰 KVM USB 스위치 4 1
# ATEN CS 22 U USB 포트 PCP 0004
# NETmate KVM 21 스위치 보급 PCD 0972
# 6 즉시 할인 쿠폰 오 피트 IEEE 1394 광 케이블 리피터 30 M
# NETmate 19 콘솔 KVM 연장 kvm 스위치 모니터 배기 분배 기
# 4 즉시 할인 쿠폰 ATEN CS 62 S USB 포트
# ATEN CS 62 S USB 포트 PCP 0001
# 4 즉시 할인 쿠폰 ATEN CS 661 USB 포트
# NETmate USB KVM 21 스위치 PCD 3016
# NETmate KVM 41 스위치 보급 PCD 0974
# KVM 2 1 고급 3 M RGB 통합 PCD 9592
# 6 즉시 할인 쿠폰 ATEN CS 1758 8 포트 PS 2 USB KVM 스위치
# NETmate KVM 연장 RGB 케이블 10 M ST 포함 PCD 1049
# 6 즉시 할인 쿠폰 ATEN CS 52 A USB 포트
# 6 즉시 할인 쿠폰 NETmate KVM 2 1 스위치 보급 케이블 포함
# 6 즉시 할인 쿠폰 4 포트 PS 2 랙 타입 KVM 스위치 KVM 스위치 4 1 PS 2 케이블
# 6 즉시 할인 쿠폰 NETmate PS 2 COMBO KVM 16 1 스위치 OSD KVM 콘솔 KVM
# 6 즉시 할인 쿠폰 NETmate KVM 2 1 스위치 케이블 포함
# 6 즉시 할인 쿠폰 NETmate KVM 4 1 스위치 마우스 클릭 킹
# 6 즉시 할인 쿠폰 ATEN CS 1216 A 16 포트 랙 타입 PS 2 KVM 스위치 CS 1216
# ATEN CS 52 A USB 포트 PCP 0009
# 6 즉시 할인 쿠폰 ATEN CE 770 USB KVM 연장 기 CE 770 USB KVM Extender
# 6 즉시 할인 쿠폰 ATEN CL 1016 16 포트 Slideaway LCD KVM 스위치 CL 1
# 6 즉시 할인 쿠폰 ATEN CL 5808 8 포트 듀얼 레일 LCD KVM 스위치 CL 5808
# 6 즉시 할인 쿠폰 ATEN CS 9138 Rackmount KVM Switches USB 포트 케이블
# 6 즉시 할인 쿠폰 ATEN CS 1758 8 포트 PS 2 USB KVM 스위치 CS 1758 USB
# 6 즉시 할인 쿠폰 ATEN CL 1008 8 포트 Slideaway LCD KVM 스위치 CL 10
# 6 즉시 할인 쿠폰 NETmate KVM 4 1 스위치 IC 714 IW KVM 공유
# 6 즉시 할인 쿠폰 8 포트 PS 2 랙 타입 KVM 스위치 KVM 스위치 8 1 PS 2 케이블
# ATEN CS 1216 A 16 포트 랙 타입 PS 2 KVM 스위치 CS 1216 A Rackmount KVM Switches
# 당일 배송 바로 출발 유니콘 UA 116 OK 정품
# 6 즉시 할인 쿠폰 TP 유니콘 UA 116 OK KVM 스위치 16 포트
# 지넷 USB 2 0 KM Switch NEXT JUC 100 Windows Windows 키 보드 마우스 공유 파일 공유 2 PC 를 하나 키 보드 마우스 제어
# 강원 전자 NETmate USB TO AUDIO USB 오디오
# 6 즉시 할인 쿠폰 KVM 스위치 16 포트 PS 2 USB KVMP 스위치 KVM 스위치 1 정성껏 배송
# IC 714 IW NETmate KVM 4 1 스위치 케이블 포함 KVM 스위치 오토 스캔 기능 마우스 클릭 킹 키 보드 모니터 마우스 1 개 제어
# NETmate KVM 4 1 스위치 보급 케이블 포함 IC 614 IW 4 대의 PC Server 를 하나 키 보드 모니터 마우스 관리
# NETmate PS 2 USB 듀얼 콘솔 COMBO KVM 16 2 스위치 OSD CASCADE 컴퓨터 용품 유무 공유기 컴퓨터 주변기기
# 6 즉시 할인 쿠폰 W PCD NETmate CAT 5 KVM 스위치 USB Dongle
# 네트워크 주변기기 DA KVM 13 M 45 CS 716 호환용 KVM
# 무료 배송 KVM 케이블 연장 5 M M F
# 4 즉시 할인 쿠폰 데이터 젠더 기타 PCDCVP 100 PS 2 10 M 15 HDBM 15 HD
# CDP 100 PS 2 10 미터 KVM 케이블 15 HDB M 15 HDB M MD 6 M MD 6 M PCD 2548
# 6 즉시 할인 쿠폰 DA KVM MF 10 CS 78 호환용 KVMCBL M F KVM 네트워크
# 4 즉시 할인 쿠폰 PCDCVP 050 PS 2 5 M 15 HDBM 15 HDBM MD 6 M MD 6 M 모니터
# 6 즉시 할인 쿠폰 DA KVM MM 2 유니콘 호환용 KVMCBL M M KVM 네트 워
# CDP 100 PS 2 10 미터 KVM 케이블 15 HDB M 15 HDB M MD 6 M MD 6 M PCD 2548
# 6 즉시 할인 쿠폰 CDP 100 PS 2 10 M 15 HDB M 15 HDB M MD 6 M
# 6 즉시 할인 쿠폰 CVP 100 PS 2 10 M 15 HDB M 15 HDB M MD 6 M MD 6 M
# ATEN 2 L 1010 P C PS 2 KVM 케이블 2 L 1010 P C PS 2 KVM Cables
# PCD NETmate USB KVM 2 1 스위치
# 6 즉시 할인 쿠폰 ATEN 2 L 1020 P C PS 2 KVM 케이블 2 L 1020 P C PS 2 K
# 4 즉시 할인 쿠폰 KVM 케이블 연장 VGA 5 M
# ATEN 2 L 5203 P PS 2 KVM 케이블 2 L 5203 P PS 2 KVM Cables PCP 0110
# KVM 케이블 연장 VGA 15 M PCD 4038
# 6 즉시 할인 쿠폰 ATEN 2 L 5003 P C PS 2 KVM 케이블 2 L 5003 P C PS 2 K
# KVM 2 1 고급 1 8 M RGB 통합 PCD 9591
# 6 즉시 할인 쿠폰 ATEN 2 L 5206 P PS 2 KVM 케이블 2 L 5206 P PS 2 KVM
# ATEN 2 L 5206 P PS 2 KVM 케이블 2 L 5206 P PS 2 KVM Cables PCP 0111
# KVM 케이블 연장 20 M M F PCD 4013
# KVM 케이블 연장 VGA 10 M PCD 4037
# 6 즉시 할인 쿠폰 ATEN 2 L 1010 P PS 2 KVM 케이블 2 L 1010 P PS 2 KVM C
# KVM 2 1 고급 1 8 M RGB 통합 PCD 9591
# 6 즉시 할인 쿠폰 CDP 030 PS 2 3 M 15 HDB 15 HDB MD 6 M
# 6 즉시 할인 쿠폰 KVM 케이블 KVM 15 MF 10 M
# 6 즉시 할인 쿠폰 ATEN 2 L 5202 P PS 2 KVM 케이블 2 L 5202 P PS 2 KVM
# 6 즉시 할인 쿠폰 NETmate Slim KVM 연장 RGB 케이블 10 M
# 4 즉시 할인 쿠폰 KVM 케이블 연장 VGA 15 M
# NETmate KVM 2 1 RGB 3 L 16100 PU 10
# M 6306 고급 NETmate PS 2 연장 Cable M F 10 M ps 2 연장 케이블
# 신원 모질라 소 전화 연결 선 1800 M
# 강원 전자 NETmate KVM 4 1 스위치 보급 케이블 포함 KVM 스위치 키 보드 마우스 모니터 컴퓨터 IC 61 당일 출발 상품
# NETmate KVM 2 1 케이블 3 M RGB
# 강원 전자 NETmate KVM 2 1 RGB 3 L 16030 PU 3
# AK 넷 메이트 넷 메이트 NETmate KVM 2 1 케이블 3 M RGB KVM 케이블 KVM 키 보드 마우스 케이블 RGB 케이블 2 IN 1 케이블 3 L 16030 PU
# NETmate KVM 2 1 케이블 3 M RGB NMC L 1630 PU
# 케이블 155268 NETmate 넷 메이트 KVM 2 1 고급 케이블 RGB 3 미터 3 3 L 16030 PU
# 6 즉시 할인 쿠폰 CVP 030 PS 2 3 M 15 HDB M 15 HDB M MD 6 M
# 4 즉시 할인 쿠폰 데이터 젠더 기타 PCDCVP 050 PS 2 5 M 15 HDBM 15 HDB
# 6 즉시 할인 쿠폰 NETmate DVI KVM M M 케이블 3 M
# 6 즉시 할인 쿠폰 DA KVM MF 1 2 CS 78 호환용 KVMCBL M F KVM 네트 워
# 6 즉시 할인 쿠폰 ATEN 2 L 5206 P PS 2 KVM 케이블 2 L 5206 P PS 2 KVM
# ...
# 팬콧 스웨 그 블록 레깅스 PPOIPLG 05 WC 6
# 5 즉시 할인 현대 Hmall 팬콧 크루 넥 POPEYE POCKET COLORATIO CREWNECK 전 컬러 택 1 PPOTACR 71 U
# 맨즈 리즘 컬러 데님 워싱 헨리 넥 셔츠 색상 black blue dark blue khaki 사이즈 48 M 50 L 구성 코튼 100
# 5 즉시 할인 롯데 백화점 공용 달러 배드 아이즈 키즈 후디짚업 PKOIPHZ 07 U 팬콧
# 팬콧 차콜 그레이 팝 아이즈 트레이닝 팬츠 PROFPPT 02 C 8
# 붐 스타일 BOOM STYLE 블 옥스포드 헨리 넥 셔츠
# pancoat AK 플라자 팬콧 PANCOAT 공용 팝 이글 팬콧 A F 롱 슬리브 팔 티셔츠 PPOIPRL 15 U P 020937890
# 팬콧 팬콧 후드 집업 POPEYES NEON POINT HOODY ZIPUP 전 컬러 택 1 PPOHAHZ 71 U
# pancoat AK PLAZA 팬콧 PANCOAT 공용 팝 아이즈 BB 글란 롱 슬리브 팔 티셔츠 PPOIPRL 91 U
# 20 즉시 할인 AK 플라자 팬콧 AK 플라자 팬콧 팝덕 여성 용 체크 셔츠 PPOIPLS 70 W
# 14 즉시 할인 팬콧 팬콧 후드 POPDUCK KID MINI LIGHT HOODY 전 컬러 택 1 PKOTAHD 02 U
# 현대 백화점 I 관 일꼬르소 델 마에스트로 바지 ICP 03 B 204 CM 컬러 감 인기 상품
# 지오 지아 모 100 솔리드 노턱 정장 팬츠 AR 1 P 141 BK
# 18 즉시 할인 아이파크 백화점 TBJ 유니 스판 슬림 스트레이트 팬츠 옵션 밸트 T 145 PT 240 P 1
# 테이 트 남성 기본 슬림핏 스 판면 팬츠 KA 4 W 0 MPL 700 B
# TATE 남성 기본 슬림핏 스판 면 팬츠 KA 4 W 0 MPL 700 B
# TATE 남성 기본 슬림핏 스판 면 팬츠 KA 4 W 0 MPL 700 B
# 신한카드 5 토키오 TOKIO 이애 널 라인 밴딩 팬츠 블루
# 지오 지아 ANDZ 면 100 솔리드 노턱 캐 주얼 팬츠 AZS 2 PP 1110 LPK 기존 148000 원
# 하프 클럽 ZIOZIA 지오 지아 ANDZ 면 100 솔리드 노턱 캐 주얼 팬츠 AZS 2 PP 1110 LPK
# AK FEEL GOLD 필 골드 HG 1012 nHG 1017 기모 잔 체크 골프 팬츠
# AK 필 골드 HG 1012 nHG 1017 기모 잔 체크 골프 팬츠
# 필 골드 HG 1012 nHG 1017 기모 잔 체크 골프 팬츠
# 토키오 TOKIO 토키오 빈티 크랙 밴딩 배기 팬츠 차콜
# 마에스트로 그레이 순모 노턱 팬츠 MAP 04 D 204 GE
# MAESTRO MAESTRO 그레이 순모 노턱 팬츠 MAP 04 D 204 GE P 019112657
# MAESTRO 그레이 순모 노턱 팬츠 MAP 04 D 204 GE 기존 245000 원
# 5 즉시 할인 조프 9 L 2 15 N 0957 FFP 0 B 102 MSM 남바
# 퍼플 로우 PURPLOW 퍼플 로우 사이드 벨트 모직 팬츠 PNFWPT 087 6270608
# 현대 Hmall 퍼플 로우 사이드 벨트 모직 팬츠 PNFWPT 087
# 스톤아일랜드 14 FW 6115 66620 V 1067 남성 와 펜로 트레이닝 팬츠
# 현대 백화점 I 관 엠 MK 5121007 Q 2015 S S 신 상품 코튼 스 트레 치 고 밀도 옥스포드 조직 팬츠
# 서빈 무릅 다트 절개 헤지 7 부 진 팬츠 SBDMJ c 9215
# FIRSTMAN 퍼스트 맨 컬러 면 스판 코인 포켓 포인트 슬림 팬츠 다크 브라운 YHFC 0113 DBR 3 P 016892812
# KB 국민카드 5 할인 13 일 BON BXHTA 4440 BONSTYLE 2014 F W 신상 베이지 칼라 슬림핏 캐 쥬얼 면 바지
# 현대 백화점 뉴발란스 MEN 레귤러핏 5 부 반바지 NBNV 521011
# 헤드 의류 사이드 포켓 남성 하프 팬츠 JHDM 53121 GY
# 1300 K 탑 보이 패치 무늬 스판 면 팬츠 HD 034
# 탑 보이 패치 무늬 스판 면 팬츠 HD 034
# 바보 사랑 탑 보이 패치 무늬 스판 면 팬츠 HD 034
# fashionplus TI FOR MEN 티아이 포맨 모 100 솔리드 노턱 정장 팬츠 MD 4 TP 21 A 5
# 티아이 포맨 모 100 솔리드 노턱 정장 팬츠 MD 4 TP 21 A 5
# 보리 보리 키즈 발레 엠버 노랑 T 셔츠 티셔츠 발레복
# 160 나이키 6 인치 쇼트 타이즈 552829 341 JPT M
# 173 나이키 9 인치 쇼트 타이즈 552830 010 JPT XL
# 163 나이키 6 인치 쇼트 타이즈 552829 547 JPT L
# 해외 Dries Van Noten Dries Van Noten Bullion Embroidered Robe 관 부가세 포함 100 정품
# 해외 메이시스 코리아 Under Armour Mens UA HeatGear ArmourVent Perf Compression Shorts Under Armour 2100007335
# 해외 드 네이비 Oldnavy Oldnavy Mens Boxer Briefs
# 해외 샵 포유 Calvin Klein Underwear CK One Hip Briefs
# 164 나이키 6 인치 쇼트 타이즈 552829 653 JPT XXL
# 160 나이키 6 인치 쇼트 타이즈 552829 341 JPT XXL
# 맨즈 스포츠 팬츠
# 해외 구매 대행 Polo Ralph Lauren 특별 통관 지정 업체 Polo Ralph Lauren Allover Pony Sleep Short
# 해외 Tommy Hilfiger 타미힐피거 Tommy Hilfiger Mens Convertible Print Woven Boxer
# 겟 유즈드 GET USED 남 로고 프린트 사각 스판 드로즈 N GERE 108 D 01 5340216
# 힙업 볼륨 뽕 팬티
# 남성 D 200 힙업 팬티
# 남성 용 힙업 팬티
# New The Him 남성 힙업 팬티 보정 웨어 보정속옷 보정 용품 여성 보정속옷 남성 보정속옷
# 푸마 바디 웨어 플래티넘 U fit 드로즈 1 종 오렌지 5 MDOFE 21
# 푸마 IT 푸마 아이티 업 블랙 드로즈 1 종 5 MDDFC 01
# 푸마 푸마 보이즈 초등 중등 드로즈 9 종 중 택일 5 BD 5 BA
# 리복 리복 정품 기능 3 종 양말 셋트 2 MYZSD 02
# 푸마 푸마 IT 5 차 볼륨 퍼플 드로즈 1 종 5 MDOFE 01
# 푸마 드로즈 M GY 6 MDOUE 01
# 푸마 바디 웨어 푸마 심 리스 3 차 박서 1 종 핑크 5 MDMFE 75
# 리복 드로즈 OR 2 MDOSE 02
# 카파 드로즈 BU PMDOSE 07
# 카파 드로즈 OR PMDOSE 02
# Lafuma 푸마 1 차 드로즈 알파 라임 TMDOSE 02
# KB 카드 5 할인 돌체앤가바나 당일 12 S S 뉴 플레이 트 PK 티셔츠 그레이 G 8 O 44 G G 7 AS 9
# 푸마 푸마 IT 4 액티브 컷 블루 5 MDOFD 53
# The Him 더힘 남성 용 힙업 팬티 X 2 개 뒷태 남성 보정 팬티 남자 힙업 팬티 보정 용
# 초 강압 보정 나시 탑 복대 나시
# 모닝스타 05007 순면 링 하운즈 여성 라운드 잠옷
# 웨 이스트 쉐이프 포켓 전대
# 무료 배송 1300 K Pink B 핑크 비 플라워 레이스 슬림 복대
# 모닝스타 24231 스윗 리본 극세사 남성 잠옷
# E 웨어 모닝스타 N 3009 쁘띠쁘 프릴 레이스 리본 여성 앙상블 세트
# S 4 SMS BYC 남성 국내 3 매입 맥시 염 남 삼각팬티 1 2212 체온조절 내복
# E 웨어 모닝스타 05314 부들부들 레이온 소재 여성 용 나시 7 부 세트
# E 웨어 모닝스타 N 0729 여 N 24117 남 쁘띠쁘 로코코 리본 남 여성 용 상
# E 웨어 모닝스타 P 23161 순면 팬더 무늬 남성 잠옷 상하 세트
# 47 즉시 할인 바디 라인 얼라이브 벨트 남여 공용 복대 1 호 24 부터 7 호 38
# E 웨어 모닝스타 A 0450 A 2450 런던 클래스 로고 자수 포인트 커플 잠옷 상하 세트
# 바디 라인 얼라이브 벨트 남여 공용 복대 1 호 24 부터 M 085283 배송 배송 배송
# 아이 셀 511 볼륨 니퍼 스킨 언더웨어 복대 보정 여성 인기
# 바디 라인 얼라이브 벨트 남여 공용 복대 1 호 24 부터 7
# 22 즉시 할인 TCOM 남성 보정속옷 언더웨어 기능 속옷 남성 보정속옷
# 모닝스타 05324 플라워 상하 잠옷 2 가지 색상
# 레이스 압박 나시 탑 복대 나시 쉐이핑
# E 웨어 모닝스타 KA 28577 KA 08577 루니툰 포켓 염 남여 커플 용 반팔 5 부
# 5 즉시 할인 쿠폰 남성 보정속옷 메타 머슬 벨트 뱃살 옆구리 살 체형 보정
# 압박 나시 탑 보정 압박 보온 기능 복대
# 남성 체형 보정 용 슬림 바디 쉐이퍼 4 종
# 푸마 바디 웨어 Line 트렁크 1 종
# 아디다스 심 리스 드로즈 패키지
# 푸마 바디 웨어 Line 트렁크 1 종
# 동 내의 푸마 남성 플래티넘 히트 웨이브 6 종
# 아디다스 심 리스 드로즈 패키지
# 무료 배송 2 1 GB 1097 도트 무늬 발달 1 단계 주니어 브라 여성
# 조 BR 756 크기 다른 하트 무늬 염 노 와이어 A 컵 브라 2 가지 색상
# 24 즉시 할인 조 801 항균 항취 가공 노 와이어 주니어 브라 여성 브
# 8 즉시 할인 항균 항취 가공 하트 쟈 가드 노 와이어 AA 컵 흰색
# 8 즉시 할인 패션 하트 패턴 노 와이어 A 컵 주니어 브
# 5 즉시 할인 크기 다른 하트 무늬 염 노 와이어 A 컵 브라
# 5 즉시 할인 항균 항취 가공 쟈 가드 리본 스티치 A 컵 흰색 주
# 5 즉시 할인 맵시 업 은사 호피 무늬 노 와이어 B 컵 브
# 스토리 버드 조 BR 729 순면 향균 향취 가공 스 위트 브라 무료 배송
# 34 즉시 할인 9612 안정 스포츠 여성 노와 여성
# 글로리 BR 1331 하트 패턴 주니어 와이어 A 컵 브라
# 24 즉시 할인 샤통 BR 1033 아기자기 구름 주니어 런닝형브 주니
# 24 즉시 할인 글로리 BR 1333 도트 바탕 고양이 주니어 와이어 A 컵 브
# 8 즉시 할인 항균 항취 가공 리본 트 염 노 와이어 AA 컵
# 14 즉시 할인 GB 1322 강아지 패턴 노 와이어 AA 컵 주니어 면 브라 브
# 14 즉시 할인 GB 1326 마음 노 와이어 2 단계 AA 컵 주니어 브라
# 14 즉시 할인 BR 762 캐 주얼 스트라이프 노 와이어 몰드 A 컵 주니
# 14 즉시 할인 BR 2455 흰색 바탕 면 소재 패션 AA 컵 노 와이어 주
# BC 카드 5 할인 GOARA 고아라 GOARA 주니어 2 단계 별 염 노 와이어 면 매쉬 브라 1 종 BR 2102 75 A 85 A 패션 플러스
# 리제 로맨틱 리본 3 단계 브라 14 S S 정상
# 리제 디저트 여 9 부원 피스 잠옷 UO 5 CS 6 P 1
# 리제 미니카 남 유아 수면 조끼 UO 7 BV 104
# 순수 스킨 와이어 브라 3 여 주니어 브래지어 14 SSJL MAXACFFF 15
# 주니어 피치 크림 몰드 브라 2 단계 기존 28000 원
# 리제 정상 판타지 유니콘 여 3 부 잠옷 UO 3 CS 301
# AK 플라자 여 주니어 퓨어 플라워 브라 3 단계 P 018127467
# 리제 정상 왈츠 위드미 여 9 부 세트 UO 5 CD 107
# 리제 CALISSE 리제 CALISSE 러블리 핑크 1 단계 브라 쥬니어 브라 UNAJB 105
# 리제 아동 속옷 AK PLAZA 리제 러블 리 핑크 1 단계 브라 UNAJB 105
# 리제 정상 기프트 빌트 런닝 UOA JB 406
# 리제 AK 플라자 리제 베이직 1 단계 브라 14 S S 정상 P 017970810
# 주니어 퓨어 플라워 몰드 브라 2 단계
# 5 즉시 할인 패션 플러스 주니어 퓨어 플라워 몰드 브라 2 단계
# 리제 러브 캣 여유 수면 조끼 UO 7 BV 103
# 리제 엔 패밀리 여 9 부 세트 U 07 CD 209
# AK PLAZA 리제 핑크 트 브라 3 단계 흰색
# 16 즉시 할인 AK 플라자 AK 플라자 리제 별 마을 브라 3 단계 흰색
# 리제 정상 플로 여 7 부 세트 UP 1 CD 302
# MOONYAMOONYA AK PLAZA 여 주니어 순수 화이트 브라 3 단계
# 주니어 순수 화이트 브라 3 단계
# 현대 백화점 II 관 순수 화이트 브라 3 주니어 3 단계 브라
# 8 즉시 할인 AK 플라자 AK 플라자 주니어 순수 화이트 브라 3 단계
# 여 주니어 순수 화이트 브라 3 단계
# AK 주니어 순수 화이트 브라 3 단계
# 리제 정상 샤인 아기 모 스키 세트 UO 7 CD 205
# AK 플라자 주니어 퓨어 플라워 와이어 브라 3 단계 P 018185674
# 리제 정상 러블 리 리본 여 나시 세트 UO 3 CD 504
# AK 피치 크림 몰드 브라 2 아이보리
# 보리 보리 피치 크림 몰드 브라 2 아이보리 P 020863370
# 리제 별 마을 브라 1 단계 흰색
# 주니어 피치 크림 브라 3 단계 기존 26000 원
# 주니어 피치 크림 브라 3 단계 베이비
# AK 주니어 피치 크림 브라 3 단계
# 조 BR 762 캐 주얼 스트라이프 노 와이어 몰드 A 컵 주니어 브라 2 가지 색상 우체국 배송
# 주니어 핑크 디어 브라 1 단계
# 스킨 허밍 브라 1
# 롯데 백화점 스킨 허밍 브라 1
# 5 즉시 할인 쿠폰 롯데 백화점 스킨 허밍 브라 1
# 현대 백화점 관 MAVACFFF 07 쥬뗌므브 2
# 숲속 친구 브라 3 15 년 S S 주니어
# AK 유 아동 MOONYA MOONYA AK 유 아동 퓨어 플라워 브라 1 5975302
# 5 즉시 할인 패션 플러스 퓨어 플라워 브라 1
# BC 카드 5 할인 Sogot 조 BR 510 일러스트 면 몰드 주니어 와이어 B 컵 브라 패션 플러스
# 리제 미니 별 프리 틴 3 단계 브라 AK 플라자 리제 카리 제 calisse 리제 파리
# 주니어 플로리스트 몰드 브라 2 단계
# 이지 엔젤 몰드 브라 3 그레이 기존 29000 원
# 위존 이첨 남여 아동 7 부 9 부 후 라이스 내의 모음 14 종 택 1 아동 내의 듀퐁 편 후 라이스
# 현대 백화점 관 비비안 브라 70 사이즈 빅사 이즈 C 컵 D 컵 E 컵 브래지어 16 종 중 택 1 BR
# 애너밸리 애너벨 리 체형 보정 브라 3 종

# %%
x_list = vectorizer.fit_transform(n_list)

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf = TfidfTransformer()
z_list = tfidf.fit_transform(x_list)

# %% [markdown]
#  * 여기서는 분류에서 가장 많이 사용하는 SVM(Support Vector Machine) 을 사용한 분류 학습을 한다.

# %%
from sklearn.svm import LinearSVC

# %%
from sklearn.grid_search import GridSearchCV

# %%
import numpy as np

# %%
svc_param = {'C':np.logspace(-2,2,40)}

# %% [markdown]
#  * grid search 를 통해서 최적의 c 파라미터를 찾는다.
#  * 5 cross validation 을 한다.

# %%
gs_svc = GridSearchCV(LinearSVC(loss='l2'),svc_param,cv=5,n_jobs=4)

# %%
gs_svc.fit(z_list, y_list)
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/svm/classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=None, tol=0.0001, verbose=0),
#        fit_params={}, iid=True, n_jobs=4,
#        param_grid={'C': array([ 0.01   ,  0.01274,  0.01624,  0.02069,  0.02637,  0.0336 ,
#         0.04281,  0.05456,  0.06952,  0.08859,  0.11288,  0.14384,
#         0.1833 ,  0.23357,  0.29764,  0.37927,  0.48329,  0.61585,
#         0.78476,  1.     ])},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %% [markdown]
#  * 현재 기본 baseline 성능은 64% 정도로 나온다. 이 성능을 높이는 것이 본 과제의 목표이다.
#  * 위 grid search 로는 c 값을 찾고, 이렇게 찾은 c 값으로 다시 train 을 해서 최종 모델을 만든다.

# %%
print gs_svc.best_params_, gs_svc.best_score_
# Out:
# {'C': 1.0} 0.7106

# %%
clf = LinearSVC(C=gs_svc.best_params_['C'])

# %%
clf.fit(z_list,y_list)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
from sklearn.externals import joblib

# %% [markdown]
#  * 만들어진 모델을 나중에도 쓰기 위해서 파일에 저장한다.
#  * 아래 형태로 저장하면, 추후에 손쉽게 load 할 수 있다.
#  * 이때 SVM 모델,  cate_name - cate_id 사전, 단어 - 단어_id,빈도수 변ㅎ

# %%
joblib.dump(clf,'classify.model',compress=3)
joblib.dump(cate_dict,'cate_dict.dat',compress=3)
joblib.dump(vectorizer,'vectorizer.dat',compress=3)
joblib.dump(tfidf,'tfidf.dat',compress=3)
# Out:
# ['tfidf.dat']

# %% [markdown]
#  * 여기까지 모델을 만든다음에 classify_server 노트북을 열고, 쭉 실행을 시키면 서버가 뜬다.
#  * 서버가 뜨면 아래처럼 실행을 시킬 수 가 있다.

# %%
import requests

# %%
name='[신한카드5%할인][예화-좋은아이들] 아동한복 여아 1076 빛이나노랑'
img=''

# %%
u='http://localhost:8887/classify?name=%s&img=%s'

# %%
r = requests.get(u%(name,img)).json()
# classify_server 이 노트북을 먼저 실행하고 나서 해야 동작한다.

# %%
print r
